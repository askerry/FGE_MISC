# %%
import os
import sys
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import glob
import numpy as np
import scipy.io
import h5py
import pandas as pd

# %%
rootdir='/mindhive/saxelab2/FGE/'
behavedir=os.path.join(rootdir, 'behavioural')
stimfile=os.path.join(rootdir, 'stimdata','FGE_stims.csv')
behavioralfiles=glob.glob(os.path.join(behavedir, 'SAX_FGE_*.FGE_main.*.mat'))

# %%
def extractbehave(bf):
    '''loads a behavioral file, returns behavioral dict. so many hacks because interfacing with .mat files is hell!'''
    #some .mats require the h5py, whereas others require scipy. lord knows why.
    try:
        b = scipy.io.loadmat(bf)
    except:
        try:
            b = hdfbehaveextract(bf)
        except:
            b = hdfbehaveextract2(bf)
    for key in b.keys():
        try:
            b[key] = list(b[key].squeeze())
        except:
            pass
    return b


def hdfbehaveextract(bf):
    '''function to extract .mats using h5py. output should be a dict with items corresponding to .mat structure fields, just as would be returned by scipy.io.loadmat'''
    bhdf = h5py.File(bf, 'r')
    bips = int(bhdf['ips'][0][0])
    brt = [float(el) for el in bhdf['RT'][0]]
    brun = [int(el) for el in bhdf['run'][0]]
    bkey = [int(el) for el in bhdf['key'][0]]
    stims_unicode = [bhdf[el] for el in bhdf['item_orders'][0]]
    bitem_orders = []
    bspm_i = bhdf['spm_inputs']
    numconditions = len(bspm_i['name'])
    bspm_inputs = []
    for c in range(numconditions):
        onsets = bhdf[bspm_i['ons'][c][0]]
        onsets = np.array([[float(el)] for el in onsets[0]])
        durations = bhdf[bspm_i['dur'][c][0]]
        durations = np.array([[el] for el in durations[0]])
        condition = ''.join(unichr(i[0]) for i in bhdf[bspm_i['name'][c][0]])
        row = ([condition], onsets, durations)
        bspm_inputs.append(row)
    bspm_inputs = bspm_inputs
    for stim in stims_unicode:
        bitem_orders.append([u''.join(unichr(i[0]) for i in stim)])
    b = {'ips': bips, 'spm_inputs': bspm_inputs, 'RT': brt, 'item_orders': bitem_orders, 'run': brun, 'key': bkey}
    return b


def hdfbehaveextract2(bf):
    '''function to extract .mats using h5py. output should be a dict with items corresponding to .mat structure fields, just as would be returned by scipy.io.loadmat'''
    bhdf = h5py.File(bf, 'r')
    bips = int(bhdf['ips'][0][0])
    brt = [float(el) for el in bhdf['RT'][0]]
    brun = [int(el) for el in bhdf['run'][0]]
    bkey = [int(el) for el in bhdf['key'][0]]
    stims_unicode = bhdf['item_orders']
    numtrials = stims_unicode.shape[1]
    bitem_orders = []
    for trial in range(numtrials):
        bitem_orders.append([u''.join(unichr(i[trial]) for i in stims_unicode.value)])
    bspm_i = bhdf['spm_inputs']
    numconditions = len(bspm_i['name'])
    bspm_inputs = []
    for c in range(numconditions):
        onsets = bhdf[bspm_i['ons'][c][0]]
        onsets = np.array([[float(el)] for el in onsets[0]])
        durations = bhdf[bspm_i['dur'][c][0]]
        durations = np.array([[el] for el in durations[0]])
        condition = ''.join(unichr(i[0]) for i in bhdf[bspm_i['name'][c][0]])
        row = ([condition], onsets, durations)
        bspm_inputs.append(row)
    bspm_inputs = bspm_inputs
    b = {'ips': bips, 'spm_inputs': bspm_inputs, 'RT': brt, 'item_orders': bitem_orders, 'run': brun, 'key': bkey}
    return b

# %%
subjects, items, intensities=[],[],[]
for bf in behavioralfiles:
    b = extractbehave(bf)
    subjid=bf[len(behavedir)+1:len(behavedir)+11]
    subjects.extend([subjid for i in b['item_orders']])
    if type(b['item_orders'][0])==str:
        itemlist=[el for el in b['item_orders']]
    else:
        itemlist=[el[0] for el in b['item_orders']]
    items.extend(itemlist)
    intensities.extend(b['key'])
intensitydf=pd.DataFrame(data={'subjid':subjects, 'items':items, 'intensities':intensities})

# %%
#mapping=pd.read_csv(stimfile)[['stimname', 'qnum']]
def fillqnum(qnum):
    if qnum<10:
        nqnum='q00%.0f' %qnum
    elif qnum<100:
        nqnum='q0%.0f' %qnum
    else:
        nqnum='q%.0f' %qnum
    return nqnum
mapping['qnum']=mapping['qnum'].apply(fillqnum)
mappingdict={row.stimname:row.qnum for index,row in mapping.iterrows()}

# %%
def addqnum(itemname, mappingdict=None):
    return mappingdict[itemname]
intensitydf['qnum']=intensitydf['items'].apply(addqnum, mappingdict=mappingdict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-2772b0cbd912> in <module>()
#       1 def addqnum(itemname, mappingdict=None):
#       2     return mappingdict[itemname]
# ----> 3 intensitydf['qnum']=intensitydf['items'].apply(addqnum, mappingdict=mappingdict)
#       4
#
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    1996             values = lib.map_infer(values, lib.Timestamp)
#    1997
# -> 1998         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    1999         if len(mapped) and isinstance(mapped[0], Series):
#    2000             from pandas.core.frame import DataFrame
#
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:51482)()
#
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/pandas/core/series.pyc in <lambda>(x)
#    1985
#    1986         if kwds or args and not isinstance(func, np.ufunc):
# -> 1987             f = lambda x: func(x, *args, **kwds)
#    1988         else:
#    1989             f = func
#
# <ipython-input-66-2772b0cbd912> in addqnum(itemname, mappingdict)
#       1 def addqnum(itemname, mappingdict=None):
# ----> 2     return mappingdict[itemname]
#       3 intensitydf['qnum']=intensitydf['items'].apply(addqnum, mappingdict=mappingdict)
#       4
#
# KeyError: u'D'

# %%
intensitydf
# Out:
#       intensities    items      subjid
# 0               2  SUR_003  SAX_FGE_01
# 1               0  EXC_009  SAX_FGE_01
# 2               0  IMP_003  SAX_FGE_01
# 3               2  APP_010  SAX_FGE_01
# 4               0  PRO_003  SAX_FGE_01
# 5               0  TER_009  SAX_FGE_01
# 6               0  DIP_005  SAX_FGE_01
# 7               0  JOY_005  SAX_FGE_01
# 8               0  DEV_006  SAX_FGE_01
# 9               0  JEA_009  SAX_FGE_01
# 10              0  EMB_001  SAX_FGE_01
# 11              0  LON_002  SAX_FGE_01
# 12              0  PAI_005  SAX_FGE_01
# 13              0  CON_010  SAX_FGE_01
# 14              0  GUI_010  SAX_FGE_01
# 15              0  ANN_007  SAX_FGE_01
# 16              0  FUR_009  SAX_FGE_01
# 17              0  DIG_006  SAX_FGE_01
# 18              0  HOP_010  SAX_FGE_01
# 19              0  NOS_006  SAX_FGE_01
# 20              0  GRA_008  SAX_FGE_01
# 21              2  EXC_002  SAX_FGE_01
# 22              4  GRA_003  SAX_FGE_01
# 23              3  DIG_007  SAX_FGE_01
# 24              2  PRO_010  SAX_FGE_01
# 25              3  GUI_002  SAX_FGE_01
# 26              1  IMP_010  SAX_FGE_01
# 27              3  TER_005  SAX_FGE_01
# 28              3  FUR_005  SAX_FGE_01
# 29              4  DEV_003  SAX_FGE_01
# ...           ...      ...         ...
# 4590            2        S  SAX_FGE_22
# 4591            2        P  SAX_FGE_22
# 4592            2        T  SAX_FGE_22
# 4593            2        D  SAX_FGE_22
# 4594            2        D  SAX_FGE_22
# 4595            1        I  SAX_FGE_22
# 4596            1        N  SAX_FGE_22
# 4597            2        P  SAX_FGE_22
# 4598            3        D  SAX_FGE_22
# 4599            2        E  SAX_FGE_22
# 4600            2        E  SAX_FGE_22
# 4601            2        G  SAX_FGE_22
# 4602            2        G  SAX_FGE_22
# 4603            1        N  SAX_FGE_22
# 4604            2        J  SAX_FGE_22
# 4605            2        H  SAX_FGE_22
# 4606            2        T  SAX_FGE_22
# 4607            1        S  SAX_FGE_22
# 4608            1        J  SAX_FGE_22
# 4609            2        F  SAX_FGE_22
# 4610            2        C  SAX_FGE_22
# 4611            2        P  SAX_FGE_22
# 4612            1        D  SAX_FGE_22
# 4613            1        I  SAX_FGE_22
# 4614            1        D  SAX_FGE_22
# 4615            2        P  SAX_FGE_22
# 4616            2        D  SAX_FGE_22
# 4617            3        A  SAX_FGE_22
# 4618            2        L  SAX_FGE_22
# 4619            1        A  SAX_FGE_22
#
# [4620 rows x 3 columns]
