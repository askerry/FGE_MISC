# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %% [markdown]
# # Setup

# %%
import pickle
import NDE as ndef
import NDIM as ndimf
import os
import pandas as pd
import stimanalysisfuncs as saf

# %%
#all the hard coding, deal with this later through cfg file
rootdir='/Users/amyskerry/dropbox/FGE_MISC/'
ndefile=os.path.join(rootdir, 'data', 'NDE.csv') #contains NDEdl.csv and the first row of the two woops (with checks manually corrected since these subjects didn't have Neutral option)
ndimfile=os.path.join(rootdir, 'data', 'NDIM.csv')
ndimcfile=os.path.join(rootdir, 'data', 'NDIMC.csv')
ndimasdfile=os.path.join(rootdir, 'data', 'NDIMASD.csv')
stimfile=os.path.join(rootdir, 'data','NDE_stims.csv')
appraisalfile=os.path.join(rootdir, 'data','appraisals.csv')
appraisalcfile=os.path.join(rootdir, 'data','appraisalsC.csv')
sentimentfile=os.path.join(rootdir,'data','stimdata','FGE_stims_sentiment.csv')
cohmetrixfile=os.path.join(rootdir,'data','stimdata','FGE_stims_cohmetrix.csv')
FGEstimfile=os.path.join(rootdir,'data','stimdata','FGE_stims.csv')
intensityfile=os.path.join(rootdir,'data','stimdata','behavioralintensity.csv')

#sentiment
#cohmetrix
#behavioral intensity

allorderedemos=['Grateful', 'Joyful','Hopeful','Excited','Proud','Impressed','Content','Nostalgic', 'Surprised','Lonely', 'Furious','Terrified','Apprehensive','Annoyed', 'Guilty', 'Disgusted','Embarrassed','Devastated', 'Disappointed', 'Jealous', 'Neutral']
subjcols=['city','country','age','gender','thoughts','response_noface','response_intune','response_nothought','response_needverbal','response_facevoice','response_surprised']
fixedcols=['item','emo','subjid','rownum', 'CVI']
appraisalsubsets={'be':[ 'afraid_dim', 'happy_dim', 'angry_dim', 'sad_dim', 'surprised_dim', 'disgusted_dim'],'va':['valence','arousal'], 'v':['valence'], 'a':['arousal']}
ndechecks={'q201':'Neutral', 'q202':'Neutral'}  
ndimchecks={'main_character':[7,5]} #avgthresh, indthresh
asdchecks={'main_character':[0,0]} #avgthresh, indthresh (different exclusion criteria)
ndevisualize=False
ndimvisualize=True

# %% [markdown]
# # Preprocessing

# %%
#analyze NDE
# %autoreload
NDE_output, orderedemos=ndef.main(ndefile, allorderedemos, ndechecks, visualize=ndevisualize)
ndimf.quicksave(NDE_output, os.path.join(rootdir, 'results', 'NDE_output.pkl'))
# Out:
# running setup for NDE...
# starting with 192 rows
# reduced to 172 intact rows
# reduced to 139 check-passing rows
# reduced from 820 to 408 columns
# item-wise results:
# overall accuracy: 0.645%
# collapsing over items:
# NDE analysis complete.

# %%
#load stimuli
stimdf=pd.read_csv(stimfile)
item2emomapping=ndimf.createitem2emomapping(stimdf)
#load appraisals
appraisalsdf,appraisalscdf=pd.read_csv(appraisalfile),pd.read_csv(appraisalcfile)
appraisals=[el for el in appraisalsdf['Dqname'].values if el not in ndimchecks.keys() and el !='emotion']
appraisalsc=[el for el in appraisalscdf['Dqname'].values if el not in ndimchecks.keys() and el !='emotion']
appraisalsc.extend(['disgusted_dim', 'surprised_dim']) #hack :[

# %%
#load and preprocess data
# %autoreload
print "working on NT exp"
ndimdf, ndimsubjdf, ndimexplicitdf=ndimf.setup(ndimfile, ndimchecks, item2emomapping, orderedemos, appraisals, subjcols, fixedcols, visualize=False) 
ndimdf.ix[1701,'altering']=5 #hack to fix an acquisition error
print "working on NT conrol"
ndimcdf, ndimcsubjdf, ndimcexplicitdf=ndimf.setup(ndimcfile, ndimchecks, item2emomapping, orderedemos, appraisalsc, subjcols, fixedcols,visualize=False) 
dfdict=ndimf.splitdf(ndimcdf, appraisalsubsets, fixedcols) #split into basicemo and valencearousal
ndimbedf,ndimvadf,ndimvdf,ndimadf=dfdict['be'],dfdict['va'],dfdict['v'],dfdict['a']
print "working on ASD exp"
ndimasddf, ndimasdsubjdf, ndimasdexplicitdf=ndimf.setup(ndimasdfile, asdchecks, item2emomapping, orderedemos, appraisals, subjcols, fixedcols,visualize=False) 
print "combining explicits"
allexplicitsdf=pd.concat([ndimcexplicitdf,ndimexplicitdf])
# Out:
# working on NT exp
# starting with 1971 rows....
# reduced to 1864 items by removing all-null entries....
# altered out of range values for 1 datapoints.....
# reduced to 1552 items by removing check-failing subjects (avgthresh=7).....
# reduced to 1520 check-passing items (indthresh=5).....
# reduced to 1520 after eliminating acquisition errors......
# added item and emo column
# reduced from 146 to 63 columns
# data from 197 unique subjects
# 6 to 11 responses per item (mean=7.600)
# working on NT conrol
# starting with 1600 rows....
# hack to convert disgusted and surprised from emos to appraisals
# reduced to 1581 items by removing all-null entries....
# altered out of range values for 0 datapoints.....
# reduced to 1565 items by removing check-failing subjects (avgthresh=7).....
# reduced to 1556 check-passing items (indthresh=5).....
# reduced to 1556 after eliminating acquisition errors......
# added item and emo column
# reduced from 52 to 33 columns
# data from 44 unique subjects
# 6 to 11 responses per item (mean=7.780)
# split dataframe into 4 dataframes: a, be, v, va
# working on ASD exp
# starting with 238 rows....
# reduced to 227 items by removing all-null entries....
# altered out of range values for 0 datapoints.....
# reduced to 227 items by removing check-failing subjects (avgthresh=0).....
# reduced to 201 check-passing items (indthresh=0).....
# reduced to 201 after eliminating acquisition errors......
# added item and emo column
# reduced from 146 to 63 columns
# data from 13 unique subjects
# 7 to 12 responses per item (mean=10.050)
# combining explicits
# NDIM.py:165: UserWarning: value out of range in row 1701: column altering has an out of range value 510.0
#   warnings.warn('value out of range in row %s: column %s has an out of range value %s' %(index, a, row[a]))

# %%
# %autoreload
#load other models/feature spaces
#raw stim --> cosine (direct similarity), twitter,
#sentiment
#cohmetrix
#behavioral intensity

FGEstimdf=pd.read_csv(stimfile, index_col=False)
cohmetrixinputdf=pd.read_csv(cohmetrixfile, index_col=False)
sentimentinputdf=pd.read_csv(sentimentfile, index_col=False)
intensityinputdf=pd.read_csv(intensityfile, index_col=False)

#
bagofwordsdf =saf.bagofwords(FGEstimdf, item2emomapping)
cosinedict = saf.pagerank(FGEstimdf,item2emomapping)
nbdf = saf.naivebayes(FGEstimdf,item2emomapping)
#figure out what cohmetrix variables to use...
cols = ["RDFRE 'Flesch Reading Ease'","PCREFz 'Text Easability PC Referential cohesion, z score'","SMCAUSv 'Causal verb incidence'","SMCAUSr 'Ratio of casual particles to causal verbs'","PCCNCz 'Text Easability PC Word concreteness, z score'","DRNEG 'Negation density, incidence'","SYNNP 'Number of modifiers per noun phrase, mean'","SYNLE 'Left embeddedness, words before main verb, mean'"]
#othercols=["PCNARz 'Text Easability PC Narrativity, z score'","WRDIMGc 'Imagability for content words, mean'","WRDMEAc 'Meaningfulness, Colorado norms, content words, mean'","WRDFAMc 'Familiarity for content words, mean'"]
#cols.extend(othercols)
excludecols = ['qnum_str','cond', 'stimname', 'text','qnum',"DESPC 'Paragraph count, number of paragraphs'","DESPL 'Paragraph length, number of sentences in a paragraph, mean'","DESPLd 'Paragraph length, number of sentences in a pragraph, standard deviation'"]
cohmetrixdf = saf.computecohmetrixspace(cohmetrixinputdf, item2emomapping, cols=[], excludecols=[])
intensitydf = saf.behavioralintensity(intensityinputdf, item2emomapping)
sentimentdf = saf.deeplearningsentiment(sentimentinputdf, item2emomapping)
# Out:
# training on 2000 item training set (Twitter).
# testing on 200 items (FGE)

# %% [markdown]
# # Modeling

# %%
allresults={} #save all results to this dict
confmatsaves={}
inputs={'labelcol':'emo', 'iterations':2, 'folds':{'train':[0], 'test':[1], 'nfolds':2}, 'comparisons':NDE_output} #alternative: comparisons-->NDE_output
modeltypes={'37dim': [ndimdf,appraisals],'37dimASD': [ndimasddf,appraisals],'basicemo': [ndimbedf,appraisalsubsets['be']],'valencearousal': [ndimvadf,appraisalsubsets['va']],'valence': [ndimvdf,appraisalsubsets['v']],'arousal': [ndimadf,appraisalsubsets['a']]}
modeltypes['cohmetrix']=[cohmetrixdf,[col for col in cohmetrixdf.columns if col not in fixedcols]]
modeltypes['naivebayes']=[nbdf, [col for col in nbdf.columns if col not in fixedcols]]
modeltypes['dlsentiment']=[sentimentdf, [col for col in sentimentdf.columns if col not in fixedcols]]
modeltypes['intensity']=[intensitydf, [col for col in intensitydf.columns if col not in fixedcols]]
modeltypes['explicits']=[allexplicitsdf, [col for col in allexplicitsdf.columns if 'extent' in col]]

# %%
modeldata,features=modeltypes[chosenmodel][0],modeltypes[chosenmodel][1]
classcol='emo'
generalizationcol=None
nfolds=2
df=modeldata
df.loc[:,'CVI']=[np.nan for el in range(len(df))]
emos=df[classcol].unique()
u=emos[0]
tempdf=df[df[classcol]==u]
cvindices=np.hstack([np.zeros(len(tempdf)/2+np.mod(len(tempdf),2)),np.ones(len(tempdf)/2)])
np.random.shuffle(cvindices)

# %%
df.head()
# Out:
#    item          emo               subjid  rownum  Grateful_extent  \
# 0  q132      Excited  Ndim21b_q009_01_950       6                9
# 1   q10      Annoyed  Ndim21b_q009_02_911       5                0
# 2    q7      Annoyed  Ndim21b_q006_02_786       4                0
# 3   q10      Annoyed  Ndim21b_q009_01_950       3                0
# 4   q57  Embarrassed  Ndim21b_q009_02_911       7                0
#
#    Joyful_extent  Hopeful_extent  Excited_extent  Proud_extent  \
# 0             10               9              10             7
# 1              0               0               0             0
# 2              0               0               2             8
# 3              3               6               3             1
# 4              0               0               0             0
#
#    Impressed_extent        ...         Terrified_extent  Apprehensive_extent  \
# 0                 5        ...                        0                    0
# 1                 0        ...                        0                    0
# 2                 0        ...                        0                   10
# 3                 2        ...                        0                    4
# 4                 0        ...                        0                   10
#
#    Annoyed_extent  Guilty_extent  Disgusted_extent  Embarrassed_extent  \
# 0               0              0                 0                   0
# 1               7              0                 0                   0
# 2               8              0                 1                   0
# 3               7              0                 5                   6
# 4               0              0                 0                   0
#
#    Devastated_extent  Disappointed_extent  Jealous_extent  CVI
# 0                  0                    0               0    1
# 1                  0                    8               0    1
# 2                  0                   10               0    0
# 3                  2                    7               4    0
# 4                  0                    0               0    1
#
# [5 rows x 25 columns]

# %%
df.ix[[float(el) for el in tempdf.index.values],'CVI']=[float(el) for el in cvindices]
#df.ix[[1,2,3, 20],'CVI']=[0,0,0, 1]
print len(cvindices)
print [type(el)==np.float64 for el in cvindices]
print len(tempdf.index.values)
print [type(el)==np.int64 for el in tempdf.index.values]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-ccc77d95554f> in <module>()
# ----> 1 df.ix[[float(el) for el in tempdf.index.values],'CVI']=[float(el) for el in cvindices]
#       2 #df.ix[[1,2,3, 20],'CVI']=[0,0,0, 1]
#       3 print len(cvindices)
#       4 print [type(el)==np.float64 for el in cvindices]
#       5 print len(tempdf.index.values)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __setitem__(self, key, value)
#     118                 indexer = self._convert_to_indexer(key, is_setter=True)
#     119
# --> 120         self._setitem_with_indexer(indexer, value)
#     121
#     122     def _has_valid_type(self, k, axis):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     446
#     447                     if len(labels) != len(value):
# --> 448                         raise ValueError('Must have equal len keys and value '
#     449                                          'when setting with an iterable')
#     450
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
df.loc[:,'CVI']=[np.nan for el in range(len(df))]
print len(df)
print df.index.values
for u in df[classcol].unique(): #for each value of classification label
    tempdf=df[df[classcol]==u]
    if not generalizationcol: #not requiring generalization across any dimension
        print len(tempdf.index.values)
        print tempdf.index.values
        cvindices=np.hstack([np.zeros(len(tempdf)/2+np.mod(len(tempdf),2)),np.ones(len(tempdf)/2)])
        np.random.shuffle(cvindices)
        print len(cvindices)
        print cvindices
        print len(df['CVI'])
        df.ix[tempdf.index.values,'CVI']=cvindices
    else: # requiring generalization across the <withinfoldcol> dimension
        generalizationuniques=tempdf[generalizationcol].unique()
        cvindices=np.hstack([np.zeros(len(generalizationuniques)/2+np.mod(len(generalizationuniques),2)),np.ones(len(generalizationuniques)/2)])
        np.random.shuffle(cvindices) 
        for gn,g in enumerate(generalizationuniques):
            innertempdf=tempdf[tempdf[generalizationcol]==g] #assign same CV index to all entries that g
            df.ix[innertempdf.index.values,'CVI']=cvindices[gn]

# %%
# %autoreload
for chosenmodel in ['explicits']:#[m for m in modeltypes.keys() if m !='37dimASD']:
    #create df that averages responses for individual items
    modeldata,features=modeltypes[chosenmodel][0],modeltypes[chosenmodel][1]
    #### model without generalization
    gencol=None
    allresults=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, gencol, inputs['iterations'], orderedemos, inputs['folds'], rootdir)
    #### model with generalization across items
    gencol='item'
    allresults=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, gencol, inputs['iterations'], orderedemos, inputs['folds'], rootdir)
    key='%s_%s' %(chosenmodel, gencol)
    confmatsaves[chosenmodel]=ndimf.makeconfdict(allresults[key], orderedemos)
ndimf.quicksave(confmatsaves, os.path.join(rootdir,'similarityspaces','NDIMsvmerrors.pkl'))
# Out:
# classifying explicits with generalization across None: 2 iterations of randomized split-half train/test
# emo
# [554      Annoyed
# 554    Disgusted
# Name: emo, dtype: object 'Annoyed'
#  1012     Lonely
# 1012    Content
# Name: emo, dtype: object 'Terrified'
#  1270    Terrified
# 1270    Terrified
# Name: emo, dtype: object 'Terrified'
#  79       Terrified
# 79    Disappointed
# Name: emo, dtype: object 'Terrified'
#  'Terrified' 'Terrified'
#  47      Terrified
# 47    Embarrassed
# Name: emo, dtype: object 'Terrified'
#  509    Apprehensive
# 509    Disappointed
# Name: emo, dtype: object
#  'Terrified' 28    Surprised
# 28      Content
# Name: emo, dtype: object
#  463    Surprised
# 463        Proud
# Name: emo, dtype: object
#  425     Surprised
# 425    Devastated
# Name: emo, dtype: object 'Surprised'
#  549    Nostalgic
# 549    Surprised
# Name: emo, dtype: object 'Surprised'
#  204    Surprised
# 204      Annoyed
# Name: emo, dtype: object
#  428    Surprised
# 428      Content
# Name: emo, dtype: object 'Surprised'
#  33    Apprehensive
# 33         Jealous
# Name: emo, dtype: object
#  102    Surprised
# 102       Joyful
# Name: emo, dtype: object
#  421    Content
# 421    Jealous
# Name: emo, dtype: object 'Content'
#  71    Content
# 71     Joyful
# Name: emo, dtype: object
#  410         Content
# 410    Apprehensive
# Name: emo, dtype: object
#  155      Content
# 155    Nostalgic
# Name: emo, dtype: object
#  1183    Content
# 1183    Furious
# Name: emo, dtype: object 'Content'
#  'Content' 'Content'
#  547    Apprehensive
# 547     Embarrassed
# Name: emo, dtype: object
#  104    Content
# 104    Hopeful
# Name: emo, dtype: object
#  663       Excited
# 663    Devastated
# Name: emo, dtype: object
#  171         Excited
# 171    Apprehensive
# Name: emo, dtype: object
#  36         Excited
# 36    Disappointed
# Name: emo, dtype: object 'Excited'
#  'Excited' 'Excited' 209    Excited
# 209    Jealous
# Name: emo, dtype: object
#  138    Excited
# 138    Annoyed
# Name: emo, dtype: object 'Excited'
#  160    Apprehensive
# 160      Devastated
# Name: emo, dtype: object 'Excited'
#  205    Grateful
# 205    Grateful
# Name: emo, dtype: object 'Grateful'
#  81     Grateful
# 81    Impressed
# Name: emo, dtype: object 'Grateful'
#  'Grateful' 'Grateful' 'Grateful' 'Grateful'
#  83    Grateful
# 83     Content
# Name: emo, dtype: object
#  82    Apprehensive
# 82    Apprehensive
# Name: emo, dtype: object
#  198     Grateful
# 198    Impressed
# Name: emo, dtype: object 'Hopeful'
#  800    Hopeful
# 800    Hopeful
# Name: emo, dtype: object
#  31    Hopeful
# 31    Content
# Name: emo, dtype: object 'Hopeful'
#  490         Hopeful
# 490    Disappointed
# Name: emo, dtype: object
#  63    Hopeful
# 63    Annoyed
# Name: emo, dtype: object
#  111    Hopeful
# 111     Guilty
# Name: emo, dtype: object 'Hopeful' 'Hopeful'
#  74    Apprehensive
# 74    Apprehensive
# Name: emo, dtype: object
#  80    Hopeful
# 80    Annoyed
# Name: emo, dtype: object
#  68    Impressed
# 68       Guilty
# Name: emo, dtype: object
#  1463    Impressed
# 1463       Joyful
# Name: emo, dtype: object
#  152    Impressed
# 152       Joyful
# Name: emo, dtype: object 'Impressed'
#  86    Impressed
# 86      Furious
# Name: emo, dtype: object
#  150    Impressed
# 150       Lonely
# Name: emo, dtype: object
#  760    Impressed
# 760     Grateful
# Name: emo, dtype: object
#  190       Impressed
# 190    Disappointed
# Name: emo, dtype: object
#  'Impressed' 'Apprehensive' 'Impressed'
#  30     Joyful
# 30    Annoyed
# Name: emo, dtype: object
#  1159    Joyful
# 1159    Joyful
# Name: emo, dtype: object 'Joyful' 'Joyful'
#  468     Joyful
# 468    Hopeful
# Name: emo, dtype: object 'Joyful'
#  830     Joyful
# 830    Annoyed
# Name: emo, dtype: object 'Joyful'
#  1414     Joyful
# 1414    Content
# Name: emo, dtype: object 'Apprehensive'
#  'Joyful' 35       Nostalgic
# 35    Disappointed
# Name: emo, dtype: object
#  192    Nostalgic
# 192      Furious
# Name: emo, dtype: object
#  73    Nostalgic
# 73    Terrified
# Name: emo, dtype: object 'Nostalgic'
#  116    Nostalgic
# 116       Lonely
# Name: emo, dtype: object 'Nostalgic'
#  119      Nostalgic
# 119    Embarrassed
# Name: emo, dtype: object 'Nostalgic'
#  39    Nostalgic
# 39       Guilty
# Name: emo, dtype: object 'Apprehensive'
#  109       Nostalgic
# 109    Disappointed
# Name: emo, dtype: object 'Proud'
#  1109        Proud
# 1109    Terrified
# Name: emo, dtype: object 'Proud'
#  'Proud' 714      Proud
# 714    Excited
# Name: emo, dtype: object
#  203        Proud
# 203    Disgusted
# Name: emo, dtype: object 'Proud'
#  108        Proud
# 108    Disgusted
# Name: emo, dtype: object 'Proud'
#  154    Annoyed
# 154    Content
# Name: emo, dtype: object 'Apprehensive'
#  735        Proud
# 735    Surprised
# Name: emo, dtype: object 'Devastated'
#  'Devastated' 94    Devastated
# 94     Disgusted
# Name: emo, dtype: object
#  'Devastated' 'Devastated'
#  1196    Devastated
# 1196        Guilty
# Name: emo, dtype: object
#  78    Devastated
# 78       Excited
# Name: emo, dtype: object 'Devastated'
#  446    Devastated
# 446    Devastated
# Name: emo, dtype: object 'Annoyed'
#  98     Devastated
# 98    Embarrassed
# Name: emo, dtype: object
#  58    Disappointed
# 58         Annoyed
# Name: emo, dtype: object
#  'Disappointed'
#  101    Disappointed
# 101         Jealous
# Name: emo, dtype: object
#  'Disappointed'
#  45    Disappointed
# 45         Jealous
# Name: emo, dtype: object
#  26    Disappointed
# 26       Impressed
# Name: emo, dtype: object
#  889    Disappointed
# 889       Surprised
# Name: emo, dtype: object
#  157    Disappointed
# 157       Terrified
# Name: emo, dtype: object
#  'Disappointed'
#  180         Annoyed
# 180    Apprehensive
# Name: emo, dtype: object
#  185    Disappointed
# 185         Excited
# Name: emo, dtype: object
#  'Disgusted' 57    Disgusted
# 57      Annoyed
# Name: emo, dtype: object
#  'Disgusted' 46    Disgusted
# 46      Jealous
# Name: emo, dtype: object
#  449     Disgusted
# 449    Devastated
# Name: emo, dtype: object
#  560    Disgusted
# 560      Furious
# Name: emo, dtype: object 'Disgusted'
#  'Disgusted' 'Disgusted'
#  789    Annoyed
# 789    Content
# Name: emo, dtype: object
#  48       Disgusted
# 48    Disappointed
# Name: emo, dtype: object
#  'Embarrassed'
#  172     Embarrassed
# 172    Apprehensive
# Name: emo, dtype: object
#  'Embarrassed'
#  593    Embarrassed
# 593        Jealous
# Name: emo, dtype: object
#  478    Embarrassed
# 478         Guilty
# Name: emo, dtype: object
#  'Embarrassed'
#  692    Embarrassed
# 692         Joyful
# Name: emo, dtype: object
#  'Embarrassed'
#  470    Embarrassed
# 470         Guilty
# Name: emo, dtype: object
#  690    Annoyed
# 690     Lonely
# Name: emo, dtype: object
#  1526    Embarrassed
# 1526      Impressed
# Name: emo, dtype: object 'Furious'
#  'Furious' 'Furious' 'Furious' 'Furious'
#  619     Furious
# 619    Grateful
# Name: emo, dtype: object 'Furious'
#  'Furious' 114    Furious
# 114    Annoyed
# Name: emo, dtype: object 'Annoyed'
#  515         Furious
# 515    Disappointed
# Name: emo, dtype: object
#  540       Guilty
# 540    Impressed
# Name: emo, dtype: object 'Guilty'
#  'Guilty' 'Guilty' 52     Guilty
# 52    Hopeful
# Name: emo, dtype: object
#  62     Guilty
# 62    Content
# Name: emo, dtype: object
#  411        Guilty
# 411    Devastated
# Name: emo, dtype: object
#  420    Guilty
# 420     Proud
# Name: emo, dtype: object
#  643    Guilty
# 643    Guilty
# Name: emo, dtype: object
#  34    Annoyed
# 34    Hopeful
# Name: emo, dtype: object
#  414    Guilty
# 414    Guilty
# Name: emo, dtype: object 'Jealous' 'Jealous'
#  'Jealous' 110    Jealous
# 110    Jealous
# Name: emo, dtype: object
#  208      Jealous
# 208    Disgusted
# Name: emo, dtype: object 'Jealous'
#  70      Jealous
# 70    Terrified
# Name: emo, dtype: object
#  262         Jealous
# 262    Apprehensive
# Name: emo, dtype: object
#  829      Jealous
# 829    Impressed
# Name: emo, dtype: object 'Annoyed'
#  1172         Jealous
# 1172    Disappointed
# Name: emo, dtype: object
#  'Lonely' 189    Lonely
# 189     Proud
# Name: emo, dtype: object
#  123         Lonely
# 123    Embarrassed
# Name: emo, dtype: object 'Lonely'
#  113     Lonely
# 113    Jealous
# Name: emo, dtype: object 'Lonely'
#  77       Lonely
# 77    Nostalgic
# Name: emo, dtype: object 'Lonely'
#  1046    Lonely
# 1046    Lonely
# Name: emo, dtype: object]
# [554      Annoyed
# 554    Disgusted
# Name: emo, dtype: object 'Annoyed'
#  1012     Lonely
# 1012    Content
# Name: emo, dtype: object 'Terrified'
#  1270    Terrified
# 1270    Terrified
# Name: emo, dtype: object 'Terrified'
#  79       Terrified
# 79    Disappointed
# Name: emo, dtype: object 'Terrified'
#  'Terrified' 'Terrified'
#  47      Terrified
# 47    Embarrassed
# Name: emo, dtype: object 'Terrified'
#  509    Apprehensive
# 509    Disappointed
# Name: emo, dtype: object
#  'Terrified' 28    Surprised
# 28      Content
# Name: emo, dtype: object
#  463    Surprised
# 463        Proud
# Name: emo, dtype: object
#  425     Surprised
# 425    Devastated
# Name: emo, dtype: object 'Surprised'
#  549    Nostalgic
# 549    Surprised
# Name: emo, dtype: object 'Surprised'
#  204    Surprised
# 204      Annoyed
# Name: emo, dtype: object
#  428    Surprised
# 428      Content
# Name: emo, dtype: object 'Surprised'
#  33    Apprehensive
# 33         Jealous
# Name: emo, dtype: object
#  102    Surprised
# 102       Joyful
# Name: emo, dtype: object
#  421    Content
# 421    Jealous
# Name: emo, dtype: object 'Content'
#  71    Content
# 71     Joyful
# Name: emo, dtype: object
#  410         Content
# 410    Apprehensive
# Name: emo, dtype: object
#  155      Content
# 155    Nostalgic
# Name: emo, dtype: object
#  1183    Content
# 1183    Furious
# Name: emo, dtype: object 'Content'
#  'Content' 'Content'
#  547    Apprehensive
# 547     Embarrassed
# Name: emo, dtype: object
#  104    Content
# 104    Hopeful
# Name: emo, dtype: object
#  663       Excited
# 663    Devastated
# Name: emo, dtype: object
#  171         Excited
# 171    Apprehensive
# Name: emo, dtype: object
#  36         Excited
# 36    Disappointed
# Name: emo, dtype: object 'Excited'
#  'Excited' 'Excited' 209    Excited
# 209    Jealous
# Name: emo, dtype: object
#  138    Excited
# 138    Annoyed
# Name: emo, dtype: object 'Excited'
#  160    Apprehensive
# 160      Devastated
# Name: emo, dtype: object 'Excited'
#  205    Grateful
# 205    Grateful
# Name: emo, dtype: object 'Grateful'
#  81     Grateful
# 81    Impressed
# Name: emo, dtype: object 'Grateful'
#  'Grateful' 'Grateful' 'Grateful' 'Grateful'
#  83    Grateful
# 83     Content
# Name: emo, dtype: object
#  82    Apprehensive
# 82    Apprehensive
# Name: emo, dtype: object
#  198     Grateful
# 198    Impressed
# Name: emo, dtype: object 'Hopeful'
#  800    Hopeful
# 800    Hopeful
# Name: emo, dtype: object
#  31    Hopeful
# 31    Content
# Name: emo, dtype: object 'Hopeful'
#  490         Hopeful
# 490    Disappointed
# Name: emo, dtype: object
#  63    Hopeful
# 63    Annoyed
# Name: emo, dtype: object
#  111    Hopeful
# 111     Guilty
# Name: emo, dtype: object 'Hopeful' 'Hopeful'
#  74    Apprehensive
# 74    Apprehensive
# Name: emo, dtype: object
#  80    Hopeful
# 80    Annoyed
# Name: emo, dtype: object
#  68    Impressed
# 68       Guilty
# Name: emo, dtype: object
#  1463    Impressed
# 1463       Joyful
# Name: emo, dtype: object
#  152    Impressed
# 152       Joyful
# Name: emo, dtype: object 'Impressed'
#  86    Impressed
# 86      Furious
# Name: emo, dtype: object
#  150    Impressed
# 150       Lonely
# Name: emo, dtype: object
#  760    Impressed
# 760     Grateful
# Name: emo, dtype: object
#  190       Impressed
# 190    Disappointed
# Name: emo, dtype: object
#  'Impressed' 'Apprehensive' 'Impressed'
#  30     Joyful
# 30    Annoyed
# Name: emo, dtype: object
#  1159    Joyful
# 1159    Joyful
# Name: emo, dtype: object 'Joyful' 'Joyful'
#  468     Joyful
# 468    Hopeful
# Name: emo, dtype: object 'Joyful'
#  830     Joyful
# 830    Annoyed
# Name: emo, dtype: object 'Joyful'
#  1414     Joyful
# 1414    Content
# Name: emo, dtype: object 'Apprehensive'
#  'Joyful' 35       Nostalgic
# 35    Disappointed
# Name: emo, dtype: object
#  192    Nostalgic
# 192      Furious
# Name: emo, dtype: object
#  73    Nostalgic
# 73    Terrified
# Name: emo, dtype: object 'Nostalgic'
#  116    Nostalgic
# 116       Lonely
# Name: emo, dtype: object 'Nostalgic'
#  119      Nostalgic
# 119    Embarrassed
# Name: emo, dtype: object 'Nostalgic'
#  39    Nostalgic
# 39       Guilty
# Name: emo, dtype: object 'Apprehensive'
#  109       Nostalgic
# 109    Disappointed
# Name: emo, dtype: object 'Proud'
#  1109        Proud
# 1109    Terrified
# Name: emo, dtype: object 'Proud'
#  'Proud' 714      Proud
# 714    Excited
# Name: emo, dtype: object
#  203        Proud
# 203    Disgusted
# Name: emo, dtype: object 'Proud'
#  108        Proud
# 108    Disgusted
# Name: emo, dtype: object 'Proud'
#  154    Annoyed
# 154    Content
# Name: emo, dtype: object 'Apprehensive'
#  735        Proud
# 735    Surprised
# Name: emo, dtype: object 'Devastated'
#  'Devastated' 94    Devastated
# 94     Disgusted
# Name: emo, dtype: object
#  'Devastated' 'Devastated'
#  1196    Devastated
# 1196        Guilty
# Name: emo, dtype: object
#  78    Devastated
# 78       Excited
# Name: emo, dtype: object 'Devastated'
#  446    Devastated
# 446    Devastated
# Name: emo, dtype: object 'Annoyed'
#  98     Devastated
# 98    Embarrassed
# Name: emo, dtype: object
#  58    Disappointed
# 58         Annoyed
# Name: emo, dtype: object
#  'Disappointed'
#  101    Disappointed
# 101         Jealous
# Name: emo, dtype: object
#  'Disappointed'
#  45    Disappointed
# 45         Jealous
# Name: emo, dtype: object
#  26    Disappointed
# 26       Impressed
# Name: emo, dtype: object
#  889    Disappointed
# 889       Surprised
# Name: emo, dtype: object
#  157    Disappointed
# 157       Terrified
# Name: emo, dtype: object
#  'Disappointed'
#  180         Annoyed
# 180    Apprehensive
# Name: emo, dtype: object
#  185    Disappointed
# 185         Excited
# Name: emo, dtype: object
#  'Disgusted' 57    Disgusted
# 57      Annoyed
# Name: emo, dtype: object
#  'Disgusted' 46    Disgusted
# 46      Jealous
# Name: emo, dtype: object
#  449     Disgusted
# 449    Devastated
# Name: emo, dtype: object
#  560    Disgusted
# 560      Furious
# Name: emo, dtype: object 'Disgusted'
#  'Disgusted' 'Disgusted'
#  789    Annoyed
# 789    Content
# Name: emo, dtype: object
#  48       Disgusted
# 48    Disappointed
# Name: emo, dtype: object
#  'Embarrassed'
#  172     Embarrassed
# 172    Apprehensive
# Name: emo, dtype: object
#  'Embarrassed'
#  593    Embarrassed
# 593        Jealous
# Name: emo, dtype: object
#  478    Embarrassed
# 478         Guilty
# Name: emo, dtype: object
#  'Embarrassed'
#  692    Embarrassed
# 692         Joyful
# Name: emo, dtype: object
#  'Embarrassed'
#  470    Embarrassed
# 470         Guilty
# Name: emo, dtype: object
#  690    Annoyed
# 690     Lonely
# Name: emo, dtype: object
#  1526    Embarrassed
# 1526      Impressed
# Name: emo, dtype: object 'Furious'
#  'Furious' 'Furious' 'Furious' 'Furious'
#  619     Furious
# 619    Grateful
# Name: emo, dtype: object 'Furious'
#  'Furious' 114    Furious
# 114    Annoyed
# Name: emo, dtype: object 'Annoyed'
#  515         Furious
# 515    Disappointed
# Name: emo, dtype: object
#  540       Guilty
# 540    Impressed
# Name: emo, dtype: object 'Guilty'
#  'Guilty' 'Guilty' 52     Guilty
# 52    Hopeful
# Name: emo, dtype: object
#  62     Guilty
# 62    Content
# Name: emo, dtype: object
#  411        Guilty
# 411    Devastated
# Name: emo, dtype: object
#  420    Guilty
# 420     Proud
# Name: emo, dtype: object
#  643    Guilty
# 643    Guilty
# Name: emo, dtype: object
#  34    Annoyed
# 34    Hopeful
# Name: emo, dtype: object
#  414    Guilty
# 414    Guilty
# Name: emo, dtype: object 'Jealous' 'Jealous'
#  'Jealous' 110    Jealous
# 110    Jealous
# Name: emo, dtype: object
#  208      Jealous
# 208    Disgusted
# Name: emo, dtype: object 'Jealous'
#  70      Jealous
# 70    Terrified
# Name: emo, dtype: object
#  262         Jealous
# 262    Apprehensive
# Name: emo, dtype: object
#  829      Jealous
# 829    Impressed
# Name: emo, dtype: object 'Annoyed'
#  1172         Jealous
# 1172    Disappointed
# Name: emo, dtype: object
#  'Lonely' 189    Lonely
# 189     Proud
# Name: emo, dtype: object
#  123         Lonely
# 123    Embarrassed
# Name: emo, dtype: object 'Lonely'
#  113     Lonely
# 113    Jealous
# Name: emo, dtype: object 'Lonely'
#  77       Lonely
# 77    Nostalgic
# Name: emo, dtype: object 'Lonely'
#  1046    Lonely
# 1046    Lonely
# Name: emo, dtype: object]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-2595e8584c28> in <module>()
#       5     #### model without generalization
#       6     gencol=None
# ----> 7     allresults=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, gencol, inputs['iterations'], orderedemos, inputs['folds'], rootdir)
#       8     #### model with generalization across items
#       9     gencol='item'
#
# /Users/amyskerry/Dropbox/FGE_MISC/code/NDIM.py in classificationwrapper(modeldata, allresults, chosenmodel, labelcol, features, gencol, iterations, orderedlabels, folds, rootdir)
#     565     result= ClassificationResult(chosenmodel, labelcol, features, gencol, iterations, orderedlabels)
#     566     print "classifying %s with generalization across %s: %s iterations of randomized split-half train/test" %(chosenmodel, gencol,iterations)
# --> 567     result.confmat, result.meanacc, result.labelaccs, result.exemplaraccs=iterativeclassification(modeldata, labelcol, features, folds, orderedlabels, exemplarcol='item', gencol=gencol, iterations=iterations)
#     568     allresults['%s_%s' %(chosenmodel, gencol)]=result
#     569     result.save(os.path.join(rootdir, 'results','%s_%s_results.pkl' %(chosenmodel, gencol)))
#
# /Users/amyskerry/Dropbox/FGE_MISC/code/NDIM.py in iterativeclassification(df, classcol, featurecols, folds, labelorder, exemplarcol, gencol, iterations)
#     469     exemplardf.loc[:,exemplarcol]=uniqueexemplars
#     470     for i in range(iterations):
# --> 471         predictions, labels, exemplarindices=classify(df,classcol, featurecols, folds, exemplarcol=exemplarcol, gencol=gencol)
#     472         confmat.append(makeconfmat(predictions, labels, labelorder))
#     473         m, ec, exemplaracc=accuracies(labels,predictions,labelorder)
#
# /Users/amyskerry/Dropbox/FGE_MISC/code/NDIM.py in classify(df, labelcol, featurenames, folds, exemplarcol, gencol)
#     437     print train_Y
#     438     clf=mcfg.SVM_model()
# --> 439     clf=clf.fit(train_X,train_Y)
#     440     predictions=clf.predict(test_X)
#     441     return predictions, test_Y, test[exemplarcol].values
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     138
#     139         X = atleast2d_or_csr(X, dtype=np.float64, order='C')
# --> 140         y = self._validate_targets(y)
#     141
#     142         sample_weight = np.asarray([]
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in _validate_targets(self, y)
#     439     def _validate_targets(self, y):
#     440         y = column_or_1d(y, warn=True)
# --> 441         cls, y = unique(y, return_inverse=True)
#     442         self.class_weight_ = compute_class_weight(self.class_weight, cls, y)
#     443         if len(cls) < 2:
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/arraysetops.pyc in unique(ar, return_index, return_inverse)
#     180             perm = ar.argsort(kind='mergesort')
#     181         else:
# --> 182             perm = ar.argsort()
#     183         aux = ar[perm]
#     184         flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
# ...
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     550             if len(self) != len(other):
#     551                 raise ValueError('Series lengths must match to compare')
# --> 552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#     554         elif isinstance(other, pd.DataFrame):  # pragma: no cover
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     531                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     532                 else:
# --> 533                     result = lib.vec_compare(x, y, op)
#     534             else:
#     535                 result = lib.scalar_compare(x, y, op)
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.vec_compare (pandas/lib.c:12337)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     561         else:
#     562
# --> 563             mask = isnull(self)
#     564
#     565             values = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in isnull(obj)
#     127     pandas.notnull: boolean inverse of pandas.isnull
#     128     """
# --> 129     return _isnull(obj)
#     130
#     131
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_new(obj)
#     137         raise NotImplementedError("isnull is not defined for MultiIndex")
#     138     elif isinstance(obj, (ABCSeries, np.ndarray)):
# --> 139         return _isnull_ndarraylike(obj)
#     140     elif isinstance(obj, ABCGeneric):
#     141         return obj._constructor(obj._data.isnull(func=isnull))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/common.pyc in _isnull_ndarraylike(obj)
#     212             result = np.zeros(values.shape, dtype=bool)
#     213         else:
# --> 214             result = np.empty(shape, dtype=bool)
#     215             vec = lib.isnullobj(values.ravel())
#     216             result[...] = vec.reshape(shape)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     690         raise ValueError("The truth value of a {0} is ambiguous. "
#     691                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 692                          .format(self.__class__.__name__))
#     693
#     694     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#save input feature spaces and rsa similarity spaces
# %autoreload
inputspaces,allrsasimspaces={},{}
rdmiterations=10
for chosenmodel in temp:#modeltypes.keys():
    df=modeltypes[chosenmodel][0]
    features=['item']
    features.extend(modeltypes[chosenmodel][1])
    rsadict=ndimf.createfeaturespace(df, features) #model inputspace
    inputspaces[chosenmodel]=rsadict
    allrsasimspaces[chosenmodel]=ndimf.makesimspaces(rsadict, item2emomapping, orderedemos, similarity='euclidean') #model similarity space (from input space)
    allrsasimspaces[chosenmodel]=confmatsaves[chosenmodel]
#specialized
allrsasimspaces['cosinesim']=ndimf.makecosineconfmat(cosinedict, orderedemos, item2emomapping)
allrsasimspaces['NDEconfmat']=ndimf.makeNDEconfmat(NDE_output['cprop'], orderedemos)
explicitdict=ndimf.createfeaturespace(allexplicitsdf, ['item']+[col for col in allexplicitsdf.columns if col not in fixedcols]) 
ndimf.quicksave(inputspaces, os.path.join(rootdir, 'similarityspaces', 'RSAmatrixinfo.pkl'))
ndimf.quicksave(allrsasimspaces, os.path.join(rootdir, 'similarityspaces', 'comparisonRDMs.pkl'))
ndimf.quicksave(explicitdict, os.path.join(rootdir, 'similarityspaces', 'NDIMexplicits.pkl'))

# %%
# %autoreload
if ndimvisualize:
    #visualize inputs
    ax1=ndimf.visualizeinputs(inputspaces, orderedemos, item2emomapping, ncols=3, collapse='emo')
    #visualize model results
    for key in allresults.keys():
        result=allresults[key]
        ndimf.visualizeclassification(result.confmat, result.labelaccs, orderedemos, comparisons=inputs['comparisons'])
        plt.tight_layout()
        plt.show()
    ax3=ndimf.visualizeRDMs(allrsasimspaces, orderedemos, ncols=3)
# Out:
# *********************************INPUT FEATURE SPACES**********************************
# *****************************REPRESENTATIONAL DISSIMILARITY MATRICES******************************

# %% [markdown]
# # Similarity Spaces

# %%
def plotsimmatrix():
        if rankcolors:
            plotmin,plotmax=None,None
        else:
            plotmin, plotmax = 0,1
        viz.simplematrix(crossrun_rdm, minspec=plotmin, maxspec=plotmax, xticklabels=axis, yticklabels=axis,
                         colorspec='RdYlBu_r', xtickrotation=90, xlabel='%s_indRSA_crossrun' % (matrixkey), rankcolors=rankcolors)

# %% [markdown]
# # Comparisons

# %%
#compare models to eachother
# %autoreload
ndimf.plotacccomparison(allresults, flags=['None', 'item'], benchmark=NDE_output['csummary']['accuracy'].mean())

# %% [markdown]
# # Dimensionality reduction

# %%
avgs=ndimdf.groupby('item')[appraisals].mean()#ndimdf.groupby('emo')[appraisals].mean()
dimlabels,dimmatrix,axislabels=avgs.columns, avgs.values.T, avgs.index

# %%
#use affinity propogation to identify clusters in the dimensions
# %autoreload
dimclusters, cluster2realmapping=ndimf.affinitypropcluster(dimmatrix, dimlabels, axislabels, dim1=0, dim2=1)
print cluster2realmapping

# %%
#kmeans
# %autoreload
dimk=ndimf.optimalKclusters1(dimmatrix)
if dimk<1:
    dimk=1
clusterdict, dimclusterresults=ndimf.kmeansclustering(dimmatrix, dimlabels, axislabels, numclust=dimk)
print clusterdict

# %%
#hierarchical clustering
# %autoreload
hierarchy=ndimf.hierarchicalcluster(dimmatrix, dimlabels, similarity='euclidean', colorthresh='default')

# %%
# %autoreload
#PCA
pcaobsscores, pcadimloadings, pcarecoveredinput=ndimf.reduction(dimmatrix.T, reductiontype='PCA')
pcaobsscores, pcadimloadings, pcarecoveredinput=ndimf.reduction(dimmatrix.T, ncomp=8, reductiontype='PCA')#set this based on first screen plot
ndimf.plotinputincomponentspace(pcaobsscores, axislabels, item2emomapping)

# %%
#ica
# %autoreload
icaobsscores, icadimloadings, icarecoveredinput=ndimf.reduction(dimmatrix.T, reductiontype='ICA')
icaobsscores, icadimloadings, icarecoveredinput=ndimf.reduction(dimmatrix.T, ncomp=8, reductiontype='ICA')#set this based on first screen plot
ndimf.plotinputincomponentspace(icaobsscores, axislabels, item2emomapping)

# %%
#compare ICA and PCA
# %autoreload
f,axes=plt.subplots(1,2)
ndimf.plotcomponentcorrs(pcaobsscores, ax=axes[0], label='pca')
ndimf.plotcomponentcorrs(icaobsscores, ax=axes[1], label='ica')

# %%
# %autoreload
ndimf.plotcomponentsininputspace(dimmatrix.T,axislabels, item2emomapping, pcadimloadings)
ndimf.plotcomponentsininputspace(dimmatrix.T,axislabels, item2emomapping, icadimloadings)

# %%
rsadeets.keys()
# Out:
# ['37dim', 'basicemo', '37dimASD', 'valencearousal', 'arousal', 'valence']
