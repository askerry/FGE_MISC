# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %% [markdown]
# # Setup

# %%
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/')
import pickle
import NDE as ndef
import NDIM as ndimf
import os
import pandas as pd
import FGE_MISC.code.behave.stimanalysisfuncs as saf
import numpy as np
import matplotlib.pyplot as plt
import FGE_MISC.code.vizfuncs as vizfuncs
from FGE_MISC.code.config import cohmetrixcfg, rootdir, cfg, dfiles #all hardcoding of paths, etc. lives in here
from joblib import Parallel, delayed  
import multiprocessing
num_cores = multiprocessing.cpu_count()
print "%s cores available for parallel processing" % num_cores

# %%
cohmetrixcfg.cols
# Out:
# ["RDFRE 'Flesch Reading Ease'",
#  "PCREFz 'Text Easability PC Referential cohesion, z score'",
#  "DESWC 'Word count, number of words'",
#  "PCCNCz 'Text Easability PC Word concreteness, z score'",
#  "DRNEG 'Negation density, incidence'",
#  "SYNNP 'Number of modifiers per noun phrase, mean'",
#  "SYNLE 'Left embeddedness, words before main verb, mean'"]

# %%
modeling=True #are you redoing the modeling or loading most recent?
simspacing=True #are you reconstructing the similarity spaces or loading most recent?
createdfs=False
#cfg.printdeets()

# %% [markdown]
# # Preprocessing

# %%
#analyze NDE
# %autoreload
NDE_output, orderedemos=ndef.main(dfiles.ndefile, cfg)
ndimf.quicksave(NDE_output, os.path.join(rootdir, 'results', 'NDE_output.pkl'))
# Out:
# running setup for NDE...
# 172 subjects, 96 females
# mean age: 33.326, sem: 0.873
# starting with 192 rows
# reduced to 172 intact rows
# reduced to 139 check-passing rows
# reduced from 820 to 408 columns
# item-wise results:
# overall accuracy: 0.645%
# one-way anova comparing classification accuracy across emotions
# F(19,180)=4.97, p=0.000000
# independent samples ttest comparing classification accuracy across positive and negative emotions
# Mneg(SEM)=0.69(0.02), Mpos(SEM)=0.58(0.02), t(198)=3.25, p=0.001356
#
# collapsing over items:
# NDE analysis complete.

# %%
#load stimuli
stimdf=pd.read_csv(dfiles.stimfile)
item2emomapping=ndimf.createitem2emomapping(stimdf)
#load appraisals
appraisalsdf,appraisalscdf=pd.read_csv(dfiles.appraisalfile),pd.read_csv(dfiles.appraisalcfile)
appraisalsdf.ix[appraisalsdf[appraisalsdf['Dqname']=='safey'].index,'Dqname']='safety' #fix typo
appraisals=[el for el in appraisalsdf['Dqname'].values if el not in cfg.ndimchecks.keys() and el !='emotion']
appraisalsc=[el for el in appraisalscdf['Dqname'].values if el not in cfg.ndimchecks.keys() and el !='emotion']+['disgusted_dim', 'surprised_dim'] #hack :[

# %%
#load and preprocess data
# %autoreload
print "working on NT exp"
ndimdf, ndimsubjdf, ndimexplicitdf=ndimf.setup(dfiles.ndimfile, cfg.ndimchecks, item2emomapping, orderedemos, appraisals, cfg.subjcols, cfg.fixedcols, visualize=False) 
ndimdf.ix[1701,'altering']=5 #hack to fix an acquisition error
print "working on NT conrol"
ndimcdf, ndimcsubjdf, ndimcexplicitdf=ndimf.setup(dfiles.ndimcfile, cfg.ndimchecks, item2emomapping, orderedemos, appraisalsc, cfg.subjcols, cfg.fixedcols,visualize=False) 
dfdict=ndimf.splitdf(ndimcdf, cfg.appraisalsubsets, cfg.fixedcols) #split into basicemo and valencearousal
ndimbedf,ndimvadf,ndimvdf,ndimadf=dfdict['be'],dfdict['va'],dfdict['v'],dfdict['a']
print "total specs across NT exp and control"
tsubjdf=ndimf.summarize(ndimdf, ndimsubjdf, ndimcdf, ndimcsubjdf)
print "working on ASD exp"
ndimasddf, ndimasdsubjdf, ndimasdexplicitdf=ndimf.setup(dfiles.ndimasdfile, cfg.asdchecks, item2emomapping, orderedemos, appraisals, cfg.subjcols, cfg.fixedcols,visualize=False) 
print "combining explicits"
allexplicitsdf=pd.concat([ndimcexplicitdf,ndimexplicitdf])
allexplicitsdf.index=range(len(allexplicitsdf))
# Out:
# working on NT exp
# starting with 1971 rows....
# reduced to 1864 items by removing all-null entries....
# altered out of range values for 1 datapoints.....
# reduced to 1552 items by removing check-failing subjects (avgthresh=7).....
# reduced to 1520 check-passing items (indthresh=5).....
# reduced to 1520 after eliminating acquisition errors......
# added item and emo column
# reduced from 146 to 63 columns
# data from 189 unique subjects
# 6 to 11 responses per item (mean=7.600, sem=0.064)
# working on NT conrol
# starting with 1600 rows....
# hack to convert disgusted and surprised from emos to appraisals
# reduced to 1581 items by removing all-null entries....
# altered out of range values for 0 datapoints.....
# reduced to 1565 items by removing check-failing subjects (avgthresh=7).....
# reduced to 1556 check-passing items (indthresh=5).....
# reduced to 1556 after eliminating acquisition errors......
# added item and emo column
# reduced from 52 to 33 columns
# data from 39 unique subjects
# 6 to 11 responses per item (mean=7.780, sem=0.093)
# split dataframe into 4 dataframes: a, be, v, va
# total specs across NT exp and control
# 3076 individual item responses, 228 subjects
# 108 females, age: mean(sem)=34.47(0.77)
# 13 to 20 responses per item (mean=15.380, sem=0.114)
# working on ASD exp
# starting with 238 rows....
# reduced to 227 items by removing all-null entries....
# altered out of range values for 0 datapoints.....
# reduced to 227 items by removing check-failing subjects (avgthresh=0).....
# reduced to 201 check-passing items (indthresh=0).....
# reduced to 201 after eliminating acquisition errors......
# added item and emo column
# reduced from 146 to 63 columns
# data from 9 unique subjects
# 7 to 12 responses per item (mean=10.050, sem=0.296)
# combining explicits
# NDIM.py:139: UserWarning:
#
# value out of range in row 1701: column altering has an out of range value 510.0

# %% [markdown]
# # Stimulus Analyses

# %%
# %autoreload
#load raw stim and other models/feature spaces
if createdfs:
    FGEstimdf=pd.read_csv(dfiles.stimfile, index_col=False)
    cohmetrixinputdf=pd.read_csv(dfiles.cohmetrixfile, index_col=False)
    RNTNinputdf=pd.read_csv(dfiles.sentimentfile, index_col=False) #generated by analyzeFGEstimsentiment.py
    intensityinputdf=pd.read_csv(dfiles.intensityfile, index_col=False)

    # compute spaces
    NDEconfdf=saf.computeNDEspace(NDE_output, item2emomapping)
    cohmetrixdf = saf.computecohmetrixspace(cohmetrixinputdf, item2emomapping, cols=cohmetrixcfg.cols, excludecols=cohmetrixcfg.excludecols)
    #bagofwordsdf =saf.bagofwords(FGEstimdf, item2emomapping)
    cosinedict, tfidfdf = saf.tfidf(FGEstimdf,item2emomapping, visualize=False)
    sentbowdf = saf.sentimentbow(FGEstimdf,item2emomapping, stemmer=None)
    intensitydf = saf.behavioralintensity(intensityinputdf, item2emomapping)
    sentrntndf = saf.sentimentrntn(RNTNinputdf, item2emomapping)
else:
    dfnames=['NDEconfdf','cohmetrixdf','tfidfdf','sentbowdf','intensitydf','sentrntndf']
    [NDEconfdf,cohmetrixdf,tfidfdf,sentbowdf,intensitydf,sentrntndf]=[ndimf.quickload(os.path.join(rootdir,'data/stimdfs','%s.pkl' %fname)) for fname in dfnames]
    print "loaded feature spaces"
# Out:
# loaded feature spaces

# %% [markdown]
# # Modeling

# %%
allresults={} #save all results to this dict
confmatsaves={}
cfg.fixedcols.append('CVI')
inputs={'labelcol':'emo', 'iterations':100, 'folds':{'train':[0], 'test':[1], 'nfolds':2}, 'comparisons':NDE_output} #alternative: comparisons-->NDE_output
modeltypes={'37dim': [ndimdf,appraisals],'37dimASD': [ndimasddf,appraisals],'basicemo': [ndimbedf,cfg.appraisalsubsets['be']],'valencearousal': [ndimvadf,cfg.appraisalsubsets['va']],'valence': [ndimvdf,cfg.appraisalsubsets['v']],'arousal': [ndimadf,cfg.appraisalsubsets['a']]}
modeltypes['NDEconfmat']=[NDEconfdf,[col for col in NDEconfdf.columns if col not in cfg.fixedcols]]
modeltypes['tfidf']=[tfidfdf,[col for col in tfidfdf.columns if col not in cfg.fixedcols]]
modeltypes['cohmetrix']=[cohmetrixdf,[col for col in cohmetrixdf.columns if col not in cfg.fixedcols]]
modeltypes['sentimentBoW']=[sentbowdf, [col for col in sentbowdf.columns if col not in cfg.fixedcols]]
modeltypes['sentimentRNTN']=[sentrntndf, [col for col in sentrntndf.columns if col not in cfg.fixedcols]]
modeltypes['intensity']=[intensitydf, [col for col in intensitydf.columns if col not in cfg.fixedcols]]
modeltypes['explicits']=[allexplicitsdf, [col for col in allexplicitsdf.columns if 'extent' in col]]

# %%
# %autoreload

# %%
#modeling parallel
import warnings
warnings.filterwarnings('ignore')
if modeling:
    modelnames=[m for m in modeltypes.keys() if m !='37dimASD']
    def classpar(chosenmodel, modeltypes, allresults, inputs, orderedemos, rootdir):
        modeldata,features=modeltypes[chosenmodel][0],modeltypes[chosenmodel][1]
        #### model without generalization
        rNone=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, None, inputs['iterations'], orderedemos, inputs['folds'], rootdir)
        #### model with generalization across items
        rItem=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, 'item', inputs['iterations'], orderedemos, inputs['folds'], rootdir)
        confmat=ndimf.makeconfdict(rItem, orderedemos)
        return rNone, rItem, confmat
    parresults = Parallel(n_jobs=num_cores)(delayed(classpar)(chosenmodel, modeltypes, allresults, inputs, orderedemos, rootdir) for chosenmodel in modelnames)  
    for chosenmodeln, chosenmodel in enumerate(modelnames):
        allresults['%s_result_%s' % (chosenmodel, 'None')] = parresults[chosenmodeln][0]
        allresults['%s_result_%s' % (chosenmodel, 'item')] = parresults[chosenmodeln][1]
        confmatsaves['%s_confs_item' %(chosenmodel)] = parresults[chosenmodeln][2]
    ndimf.quicksave(confmatsaves, os.path.join(rootdir,'similarityspaces','NDIMsvmerrors.pkl'))
    ndimf.quicksave(allresults, os.path.join(rootdir,'results','NDIMRESULTS.pkl'))
else:
    confmatsaves=ndimf.quickload(os.path.join(rootdir,'similarityspaces','NDIMsvmerrors.pkl'))
    allresults=ndimf.quickload(os.path.join(rootdir,'results','NDIMRESULTS.pkl'))
    print "loaded allresults and confmatsaves"
# Out:
# classifying 37dim with generalization across None: 100 iterations of randomized split-half train/test
# classifying valence with generalization across None: 100 iterations of randomized split-half train/test
# classifying sentimentRNTN with generalization across None: 100 iterations of randomized split-half train/test
# classifying tfidf with generalization across None: 100 iterations of randomized split-half train/test
# classifying NDEconfmat with generalization across None: 100 iterations of randomized split-half train/test
# classifying intensity with generalization across None: 100 iterations of randomized split-half train/test
# classifying valencearousal with generalization across None: 100 iterations of randomized split-half train/test
# classifying explicits with generalization across None: 100 iterations of randomized split-half train/test
# classifying arousal with generalization across None: 100 iterations of randomized split-half train/test
# classifying basicemo with generalization across None: 100 iterations of randomized split-half train/test
# classifying cohmetrix with generalization across None: 100 iterations of randomized split-half train/test
# classifying sentimentBoW with generalization across None: 100 iterations of randomized split-half train/test
# overall classification across iterations: 72.67%overall classification across iterations: 15.59%overall classification across iterations: 5.39%overall classification across iterations: 15.35%overall classification across iterations: 87.40%overall classification across iterations: 11.57%overall classification across iterations: 23.52%overall classification across iterations: 71.92%overall classification across iterations: 12.92%overall classification across iterations: 39.87%overall classification across iterations: 9.07%overall classification across iterations: 6.21%
#
#
#
#
#
#
#
#
#
#
#
# classifying 37dim with generalization across item: 100 iterations of randomized split-half train/test
# classifying valence with generalization across item: 100 iterations of randomized split-half train/test
# classifying sentimentRNTN with generalization across item: 100 iterations of randomized split-half train/test
# classifying tfidf with generalization across item: 100 iterations of randomized split-half train/test
# classifying NDEconfmat with generalization across item: 100 iterations of randomized split-half train/test
# classifying intensity with generalization across item: 100 iterations of randomized split-half train/test
# classifying valencearousal with generalization across item: 100 iterations of randomized split-half train/test
# classifying explicits with generalization across item: 100 iterations of randomized split-half train/test
# classifying arousal with generalization across item: 100 iterations of randomized split-half train/test
# classifying basicemo with generalization across item: 100 iterations of randomized split-half train/test
# classifying cohmetrix with generalization across item: 100 iterations of randomized split-half train/test
# classifying sentimentBoW with generalization across item: 100 iterations of randomized split-half train/test
# overall classification across iterations: 56.58%overall classification across iterations: 17.80%overall classification across iterations: 5.46%overall classification across iterations: 15.34%overall classification across iterations: 87.42%overall classification across iterations: 11.82%overall classification across iterations: 26.03%overall classification across iterations: 67.04%overall classification across iterations: 14.27%overall classification across iterations: 44.02%overall classification across iterations: 9.52%overall classification across iterations: 6.33%

# %% [raw]
# %autoreload
# #non parallel
# if modeling:
#     for chosenmodel in [m for m in modeltypes.keys() if m !='37dimASD']:
#         #create df that averages responses for individual items
#         modeldata,features=modeltypes[chosenmodel][0],modeltypes[chosenmodel][1]
#         #### model without generalization
#         allresults=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, None, inputs['iterations'], orderedemos, inputs['folds'], rootdir)
#         #### model with generalization across items
#         allresults=ndimf.classificationwrapper(modeldata,allresults, chosenmodel, inputs['labelcol'], features, 'item', inputs['iterations'], orderedemos, inputs['folds'], rootdir)
#         confmatsaves['%s_confs_%s' %(chosenmodel, gencol)]=ndimf.makeconfdict(allresults['%s_result_%s' %(chosenmodel, gencol)], orderedemos)
#     ndimf.quicksave(confmatsaves, os.path.join(rootdir,'similarityspaces','NDIMsvmerrors.pkl'))
#     ndimf.quicksave(allresults, os.path.join(rootdir,'results','NDIMRESULTS.pkl'))
# else:
#     confmatsaves=ndimf.quickload(os.path.join(rootdir,'similarityspaces','NDIMsvmerrors.pkl'))
#     allresults=ndimf.quickload(os.path.join(rootdir,'results','NDIMRESULTS.pkl'))
#     print "loaded allresults and confmatsaves"

# %%
# %autoreload
m2bresults={}
for k in allresults.keys():
    m2bresults[k]=ndimf.comparemodel2behavior(allresults[k], NDE_output, orderedemos, simtype='pearsonr')
ndimf.quicksave(m2bresults, os.path.join(rootdir,'results','M2BRESULTS.pkl'))
print "correlated model outputs and behavior"
# Out:
# correlated model outputs and behavior

# %%
# %autoreload
#in progress individual analysis
indresults={}
for chosenmodel in ['37dim', 'basicemo', 'valencearousal', 'valence', 'arousal']:
    print chosenmodel
    modeldata,features=modeltypes[chosenmodel][0],modeltypes[chosenmodel][1]
    indresults[chosenmodel]=ndimf.individualizedmodeling(modeldata, ndimexplicitdf, chosenmodel, inputs['labelcol'], features, 'item', inputs['iterations'], orderedemos, inputs['folds'], rootdir)
ndimf.quicksave(indresults, os.path.join(rootdir,'results','INDRESULTS.pkl'))
# Out:
# 37dim
# training on 1042 pass items, testing on 292 failed items:
# accuracy (relative to intended emotion): 0.349, user-consistency (prediction aligns with user max): 0.120
# basicemo
# training on 765 pass items, testing on 233 failed items:
# accuracy (relative to intended emotion): 0.305, user-consistency (prediction aligns with user max): 0.039
# valencearousal
# training on 765 pass items, testing on 233 failed items:
# accuracy (relative to intended emotion): 0.150, user-consistency (prediction aligns with user max): 0.052
# valence
# training on 765 pass items, testing on 233 failed items:
# accuracy (relative to intended emotion): 0.133, user-consistency (prediction aligns with user max): 0.086
# arousal
# training on 765 pass items, testing on 233 failed items:
# accuracy (relative to intended emotion): 0.129, user-consistency (prediction aligns with user max): 0.039

# %% [markdown]
# # Similarity Spaces

# %%
#save input feature spaces and rsa similarity spaces
# %autoreload
if simspacing:
    inputspaces,allrsasimspaces={},{}
    rdmiterations=100
    for chosenmodel in [m for m in modeltypes.keys() if m !='37dimASD']:
        df=modeltypes[chosenmodel][0]
        features=['item']+modeltypes[chosenmodel][1]
        rsadict=ndimf.createfeaturespace(df, features) #model inputspace
        inputspaces[chosenmodel]=rsadict
        allrsasimspaces['%s_rdm' %chosenmodel]=ndimf.makesimspaces(rsadict, item2emomapping, orderedemos, similarity='euclidean') #model similarity space (from input space)
        for flag in ['item']:
            allrsasimspaces["%s_confs_%s" %(chosenmodel,flag)]=ndimf.makeconfRDM(flag, chosenmodel, confmatsaves) #specialized
    allrsasimspaces['NDEconfmat_raw']=ndimf.makeNDEconfmat(NDE_output['cprop'], orderedemos)
    explicitdict=ndimf.createfeaturespace(allexplicitsdf, ['item']+[col for col in allexplicitsdf.columns if col not in cfg.fixedcols]) 
    ndimf.quicksave(inputspaces, os.path.join(rootdir, 'similarityspaces', 'RSAmatrixinfo.pkl'))
    ndimf.quicksave(allrsasimspaces, os.path.join(rootdir, 'similarityspaces', 'comparisonRDMs.pkl'))
    ndimf.quicksave(explicitdict, os.path.join(rootdir, 'similarityspaces', 'NDIMexplicits.pkl'))
    print "created similarity spaces acros %s iterations of split-half euclidean distances" %(100)
else:
    inputspaces=ndimf.quickload(os.path.join(rootdir, 'similarityspaces', 'RSAmatrixinfo.pkl'))
    allrsasimspaces=ndimf.quickload(os.path.join(rootdir, 'similarityspaces', 'comparisonRDMs.pkl'))
    explicitdict=ndimf.quickload(os.path.join(rootdir, 'similarityspaces', 'NDIMexplicits.pkl'))
# Out:
# created similarity spaces acros 100 iterations of split-half euclidean distances

# %% [markdown]
# # Dimensionality reduction

# %%
avgs=ndimdf.groupby('item')[appraisals].mean()#ndimdf.groupby('emo')[appraisals].mean()
dimlabels,dimmatrix,axislabels=avgs.columns, avgs.values.T, avgs.index

# %%
#use affinity propogation to identify clusters in the dimensions
# %autoreload
dimclusters, cluster2realmapping=ndimf.affinitypropcluster(dimmatrix, dimlabels, axislabels, dim1=0, dim2=1)
print cluster2realmapping
# Out:
# Estimated number of clusters: 7
# {'control': ['control', 'self_cause', 'altering'], 'relationship_influence': ['relationship_influence', 'people', 'close_others', 'mental_states'], 'self_consistency': ['self_consistency', 'agent_intention', 'self_involvement', 'moral', 'fairness', 'goal_consistency', 'selfesteem', 'pleasantness', 'coping', 'freedom', 'certainty', 'future'], 'attention': ['danger', 'attention', 'remember'], 'familiarity': ['past', 'familiarity', 'expectedness', 'repetition'], 'safey': ['bodily_disease', 'safey'], 'psychological_change': ['others_knowledge', 'suddenness', 'agent_situation', 'occurred', 'relevance', 'agent_cause', 'consequences', 'pressure', 'psychological_change', 'knowledge_change']}

# %%
#kmeans
# %autoreload
dimk=ndimf.optimalKclusters1(dimmatrix)
if dimk<1:
    dimk=1
clusterdict, dimclusterresults=ndimf.kmeansclustering(dimmatrix, dimlabels, axislabels, numclust=dimk)
print clusterdict
# Out:
# {0: ['agent_intention', 'altering', 'certainty', 'control', 'expectedness', 'fairness', 'familiarity', 'goal_consistency', 'past', 'pleasantness', 'repetition', 'self_cause', 'self_consistency', 'selfesteem'], 1: ['agent_situation', 'bodily_disease', 'close_others', 'consequences', 'future', 'knowledge_change', 'mental_states', 'others_knowledge', 'people', 'pressure', 'psychological_change', 'relationship_influence', 'relevance', 'safey', 'suddenness'], 2: ['agent_cause', 'attention', 'coping', 'danger', 'freedom', 'moral', 'occurred', 'remember', 'self_involvement']}

# %%
#hierarchical clustering
# %autoreload
hierarchy=ndimf.hierarchicalcluster(dimmatrix, dimlabels, similarity='euclidean', colorthresh='default')

# %%
# %autoreload
#PCA
pcaobsscores, pcadimloadings, pcarecoveredinput, pcavarexplained=ndimf.reduction(dimmatrix.T, reductiontype='PCA')
pcaobsscores, pcadimloadings, pcarecoveredinput, pcavarexplained=ndimf.reduction(dimmatrix.T, ncomp=14, reductiontype='PCA')#set this based on first screen plot
vizfuncs.plotinputincomponentspace(pcaobsscores, axislabels, item2emomapping, plotlabels=False)
vizfuncs.plotdimensionsincomponentspace(pcadimloadings, dimlabels, mapping=None, componentindices=[0, 1, 2], title=None)
ndimf.printhighlowloaders(pcadimloadings, pcavarexplained, dimlabels)
# Out:
# reduced to 38 dimensions
# explaining 100.000% of variance
# reduced to 14 dimensions
# explaining 89.396% of variance
# component 0 (explaining 34.47% of variance):
#     high loaders= pleasantness, goal_consistency, fairness (0.4,0.3,0.3)
#     low loaders= safey, agent_situation, pressure (-0.2,-0.2,-0.2)
# component 1 (explaining 12.97% of variance):
#     high loaders= people, relationship_influence, close_others (0.4,0.4,0.3)
#     low loaders= agent_situation, coping, familiarity (-0.1,-0.1,-0.1)
# component 2 (explaining 10.41% of variance):
#     high loaders= self_cause, control, safey (0.4,0.3,0.3)
#     low loaders= agent_situation, danger, others_knowledge (-0.2,-0.2,-0.2)
# component 3 (explaining 6.46% of variance):
#     high loaders= self_cause, close_others, repetition (0.3,0.3,0.3)
#     low loaders= suddenness, pleasantness, goal_consistency (-0.3,-0.3,-0.3)
# component 4 (explaining 5.02% of variance):
#     high loaders= bodily_disease, occurred, suddenness (0.4,0.3,0.3)
#     low loaders= pressure, expectedness, repetition (-0.2,-0.2,-0.2)
# component 5 (explaining 4.23% of variance):
#     high loaders= bodily_disease, moral, close_others (0.3,0.3,0.2)
#     low loaders= agent_intention, altering, mental_states (-0.4,-0.2,-0.1)
# component 6 (explaining 3.50% of variance):
#     high loaders= danger, self_cause, suddenness (0.3,0.3,0.2)
#     low loaders= agent_intention, repetition, expectedness (-0.4,-0.3,-0.2)
# component 7 (explaining 2.76% of variance):
#     high loaders= occurred, consequences, others_knowledge (0.6,0.3,0.2)
#     low loaders= close_others, bodily_disease, altering (-0.3,-0.2,-0.1)
# component 8 (explaining 2.31% of variance):
#     high loaders= people, others_knowledge, mental_states (0.6,0.4,0.2)
#     low loaders= relationship_influence, consequences, self_involvement (-0.3,-0.2,-0.2)
# component 9 (explaining 1.75% of variance):
#     high loaders= past, safey, close_others (0.5,0.2,0.2)
#     low loaders= bodily_disease, danger, future (-0.3,-0.3,-0.2)
# component 10 (explaining 1.66% of variance):
#     high loaders= past, knowledge_change, future (0.4,0.3,0.2)
#     low loaders= self_involvement, close_others, bodily_disease (-0.3,-0.2,-0.2)
# component 11 (explaining 1.40% of variance):
#     high loaders= safey, freedom, expectedness (0.3,0.2,0.2)
#     low loaders= suddenness, repetition, past (-0.4,-0.3,-0.3)
# component 12 (explaining 1.37% of variance):
#     high loaders= others_knowledge, agent_intention, self_cause (0.6,0.5,0.2)
#     low loaders= familiarity, consequences, safey (-0.2,-0.2,-0.2)
# component 13 (explaining 1.09% of variance):
#     high loaders= repetition, knowledge_change, altering (0.4,0.3,0.2)
#     low loaders= past, moral, pressure (-0.4,-0.2,-0.2)

# %%
#ica
# %autoreload
icaobsscores, icadimloadings, icarecoveredinput, icavarexplained=ndimf.reduction(dimmatrix.T, reductiontype='ICA')
icaobsscores, icadimloadings, icarecoveredinput, icavarexplained=ndimf.reduction(dimmatrix.T, ncomp=8, reductiontype='ICA')#set this based on first screen plot
vizfuncs.plotinputincomponentspace(icaobsscores, axislabels, item2emomapping, plotlabels=False)
vizfuncs.plotdimensionsincomponentspace(icadimloadings, dimlabels, mapping=None, componentindices=[0, 1, 2], title=None)
ndimf.printhighlowloaders(icadimloadings, dimlabels)
# Out:
# reduced to 38 dimensions
# reduced to 8 dimensions
# component 0.... high loaders= occurred,consequences,others_knowledge; low loaders= close_others, bodily_disease, altering
# component 1.... high loaders= repetition,agent_intention,expectedness; low loaders= control, suddenness, altering
# component 2.... high loaders= moral,others_knowledge,close_others; low loaders= agent_cause, repetition, altering
# component 3.... high loaders= expectedness,self_cause,familiarity; low loaders= agent_situation, selfesteem, agent_cause
# component 4.... high loaders= bodily_disease,safey,occurred; low loaders= agent_cause, pressure, people
# component 5.... high loaders= pleasantness,selfesteem,goal_consistency; low loaders= pressure, repetition, expectedness
# component 6.... high loaders= self_involvement,pressure,relevance; low loaders= relationship_influence, people, mental_states
# component 7.... high loaders= future,relevance,safey; low loaders= danger, agent_cause, repetition

# %%
#compare ICA and PCA
# %autoreload
f,axes=plt.subplots(1,2, figsize=[10,4])
vizfuncs.plotcomponentcorrs(pcaobsscores, ax=axes[0], label='pca')
vizfuncs.plotcomponentcorrs(icaobsscores, ax=axes[1], label='ica')

# %%
# %autoreload
vizfuncs.plotcompsininputspace(dimmatrix.T, axislabels, pcadimloadings, pcavarexplained, item2emomapping, dimindices=[0, 1, 2], componentindices=[0, 1], constant=100)
vizfuncs.plotcompsininputspace(dimmatrix.T, axislabels, icadimloadings, pcavarexplained, item2emomapping, dimindices=[0, 1, 2], componentindices=[0, 1], constant=10000)

# %%
r=.6
n=30
import math

# %%
stderr = 1.0 / math.sqrt(n - 3)
delta = 1.96 * stderr
lower = math.tanh(math.atanh(r) - delta)
upper = math.tanh(math.atanh(r) + delta)

# %%
print lower
print upper
# Out:
# 0.305835784954
# 0.789592805036
