# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSA'#"_matched_rois" #tag on the exp object
savetag='_RSA'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
# %autoreload
roi_summaries={}
for roi in roilist:
    filename='%sResultsSummary_%s.pkl' %(analdir, roi)
    rs=mum.loadpickledobject(filename)
    roi_summaries[roi]=rs
    rs.summarize_grn2models(models2show=vizcfg.modelkeys, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4])
    rs.summarize_grn2modelsRFX(models2show=vizcfg.modelkeys,modelcolors=vizcfg.modelcolors,ylim=[-.05,.20],errorbars='bs', noiseceiling=rs.noiseceiling)#'ws'
    rs.summarize_grnmodelcomparisonsRFX(models2show=vizcfg.modelkeys, showstats=['37dim_rdm'])
# Out:
# 37dim_rdm: corr(SEM)=0.26(0.09), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.14(0.02), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.17(0.02), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.14(0.13), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.17(0.13), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.06(0.09), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.10(0.08), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.07(0.03), p(permutation test)=0.000
# ease_rdm: corr(SEM)=0.05(0.08), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.14(0.05), p(permutation test)=0.000
# bagofwordsdf_rdm: corr(SEM)=0.11(0.07), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.25(0.08), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.09(0.04), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.09(0.01), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.07, M2=0.07, z(21)=0.05, p=0.961.
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.65, p=0.008. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.07, z(21)=1.96, p=0.050. ***
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.03, M2=0.07, z(21)=2.13, p=0.033. ***
# 37dim_rdm_VS_pc2_rdm: M1=0.07, M2=0.02, z(21)=2.42, p=0.016. ***
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.07, p=0.002. ***
# 37dim_rdm_VS_ease_rdm: M1=0.07, M2=0.00, z(21)=2.91, p=0.004. ***
# arousal_rdm_VS_37dim_rdm: M1=0.05, M2=0.07, z(21)=0.89, p=0.372.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.01, M2=0.07, z(21)=2.97, p=0.003. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.78, p=0.000. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.39, p=0.017. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.32, p=0.020. ***
# syntax_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.55, p=0.011. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=1.96, p=0.050. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=2.94, p=0.003. ***
# 37dim_rdm: corr(SEM)=0.24(0.07), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.11(0.01), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.02), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.10(0.11), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.19(0.10), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.13(0.06), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.07(0.05), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.04(0.03), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=-0.01(0.02), p(permutation test)=0.333
# ease_rdm: corr(SEM)=0.01(0.09), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.11(0.07), p(permutation test)=0.000
# bagofwordsdf_rdm: corr(SEM)=0.08(0.04), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.12(0.03), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.21(0.11), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.10(0.01), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.06, M2=0.06, z(21)=0.94, p=0.346.
# pc1_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=2.06, p=0.039. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=1.96, p=0.050. ***
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=1.57, p=0.115.
# 37dim_rdm_VS_pc2_rdm: M1=0.06, M2=0.02, z(21)=2.06, p=0.039. ***
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=3.23, p=0.001. ***
# 37dim_rdm_VS_ease_rdm: M1=0.06, M2=-0.00, z(21)=2.55, p=0.011. ***
# arousal_rdm_VS_37dim_rdm: M1=0.05, M2=0.06, z(21)=0.54, p=0.592.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=1.96, p=0.050. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=2.94, p=0.003. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(21)=2.74, p=0.006. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(21)=2.39, p=0.017. ***
# syntax_rdm_VS_37dim_rdm: M1=0.00, M2=0.06, z(21)=3.10, p=0.002. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.05, M2=0.06, z(21)=1.25, p=0.211.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.84, p=0.005. ***
# 37dim_rdm: corr(SEM)=0.21(0.08), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.11(0.02), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.03), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.13), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.15(0.13), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.07(0.08), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.11(0.03), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.08(0.10), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.08(0.04), p(permutation test)=0.000
# ease_rdm: corr(SEM)=0.02(0.05), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.09(0.04), p(permutation test)=0.000
# bagofwordsdf_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.01), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.20(0.06), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.08(0.03), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.08(0.03), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.06, M2=0.06, z(20)=0.09, p=0.931.
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=2.24, p=0.025. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=1.37, p=0.170.
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=1.93, p=0.054.
# 37dim_rdm_VS_pc2_rdm: M1=0.06, M2=0.02, z(20)=1.86, p=0.063.
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=2.62, p=0.009. ***
# 37dim_rdm_VS_ease_rdm: M1=0.06, M2=0.00, z(20)=2.80, p=0.005. ***
# arousal_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=0.92, p=0.357.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(20)=2.31, p=0.021. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=3.28, p=0.001. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=1.72, p=0.085.
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=2.42, p=0.016. ***
# syntax_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=2.10, p=0.035. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=2.14, p=0.033. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=2.28, p=0.023. ***
# 37dim_rdm: corr(SEM)=0.17(0.03), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.08(0.02), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.09(0.01), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.06(0.04), p(permutation test)=0.333
# arousal_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.14(0.09), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.09(0.01), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=-0.02(0.03), p(permutation test)=0.333
# ease_rdm: corr(SEM)=0.07(0.07), p(permutation test)=0.000
# tfidf_rdm: corr(SEM)=0.16(0.05), p(permutation test)=0.000
# bagofwordsdf_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.04), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.14(0.01), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.08(0.01), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.04, M2=0.05, z(21)=1.54, p=0.123.
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=2.19, p=0.028. ***
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=1.83, p=0.067.
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.03, M2=0.05, z(21)=0.76, p=0.445.
# 37dim_rdm_VS_pc2_rdm: M1=0.05, M2=0.03, z(21)=1.35, p=0.178.
# valence_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=2.84, p=0.005. ***
# 37dim_rdm_VS_ease_rdm: M1=0.05, M2=0.01, z(21)=1.96, p=0.050. ***
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.05, z(21)=1.35, p=0.178.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.04, M2=0.05, z(21)=0.80, p=0.426.
# basicemo_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=2.78, p=0.006. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.03, M2=0.05, z(21)=1.18, p=0.236.
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.01, M2=0.05, z(21)=2.00, p=0.046. ***
# syntax_rdm_VS_37dim_rdm: M1=0.00, M2=0.05, z(21)=3.00, p=0.003. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.04, M2=0.05, z(21)=0.08, p=0.935.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.05, M2=0.02, z(21)=2.91, p=0.004. ***
# 37dim_rdm: corr(SEM)=0.28(0.04), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.20(0.04), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.20(0.03), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.18(0.08), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.10), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.08(0.08), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.04(0.02), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.17(0.05), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.08(0.04), p(permutation test)=0.000
# ease_rdm: corr(SEM)=0.08(0.09), p(permutation test)=0.000
# tfidf_rdm: corr(SEM)=0.08(0.12), p(permutation test)=0.333
# bagofwordsdf_rdm: corr(SEM)=0.08(0.06), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.07(0.02), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.24(0.06), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.09(0.05), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.07(0.06), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.07, M2=0.08, z(19)=2.09, p=0.037. ***
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=2.73, p=0.006. ***
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=3.25, p=0.001. ***
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=2.99, p=0.003. ***
# 37dim_rdm_VS_pc2_rdm: M1=0.08, M2=0.02, z(19)=3.14, p=0.002. ***
# valence_rdm_VS_37dim_rdm: M1=0.05, M2=0.08, z(19)=3.10, p=0.002. ***
# 37dim_rdm_VS_ease_rdm: M1=0.08, M2=0.02, z(19)=2.50, p=0.012. ***
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.08, z(19)=3.10, p=0.002. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=2.80, p=0.005. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.06, M2=0.08, z(19)=3.10, p=0.002. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.05, M2=0.08, z(19)=1.79, p=0.073.
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.01, M2=0.08, z(19)=3.14, p=0.002. ***
# syntax_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=3.06, p=0.002. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=3.06, p=0.002. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.08, M2=0.06, z(19)=2.97, p=0.003. ***
# 37dim_rdm: corr(SEM)=0.21(0.09), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.03), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.14(0.02), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.09), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.11(0.14), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.11(0.06), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.01(0.01), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.08(0.06), p(permutation test)=0.333
# syntax_rdm: corr(SEM)=0.02(0.02), p(permutation test)=0.333
# ease_rdm: corr(SEM)=0.03(0.04), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.05(0.08), p(permutation test)=0.333
# bagofwordsdf_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# pc0_rdm: corr(SEM)=0.17(0.01), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.09(0.02), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.12(0.04), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.05, M2=0.06, z(19)=2.15, p=0.032. ***
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=1.79, p=0.073.
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=2.20, p=0.028. ***
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=1.34, p=0.179.
# 37dim_rdm_VS_pc2_rdm: M1=0.06, M2=0.03, z(19)=1.75, p=0.079.
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=2.97, p=0.003. ***
# 37dim_rdm_VS_ease_rdm: M1=0.06, M2=0.00, z(19)=2.43, p=0.015. ***
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=1.87, p=0.062.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=1.98, p=0.048. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=2.31, p=0.021. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=2.05, p=0.040. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.00, M2=0.06, z(19)=2.87, p=0.004. ***
# syntax_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(19)=3.02, p=0.002. ***
# tfidf_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=2.24, p=0.025. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=3.47, p=0.001. ***
# 37dim_rdm: corr(SEM)=0.12(0.04), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.05(0.02), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.05(0.08), p(permutation test)=0.333
# arousal_rdm: corr(SEM)=0.08(0.06), p(permutation test)=0.333
# sentimentBoW_rdm: corr(SEM)=0.07(0.10), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.00(0.06), p(permutation test)=0.333
# cohmetrix_rdm: corr(SEM)=0.14(0.02), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.02(0.01), p(permutation test)=0.333
# ease_rdm: corr(SEM)=0.04(0.09), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.13(0.08), p(permutation test)=0.333
# bagofwordsdf_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.05(0.02), p(permutation test)=0.333
# pc0_rdm: corr(SEM)=0.06(0.03), p(permutation test)=0.000
# pc1_rdm: corr(SEM)=0.07(0.02), p(permutation test)=0.000
# pc2_rdm: corr(SEM)=0.11(0.06), p(permutation test)=0.000
# pc0_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=2.68, p=0.007. ***
# pc1_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=1.11, p=0.267.
# intensity_rdm_VS_37dim_rdm: M1=0.00, M2=0.03, z(17)=1.63, p=0.102.
# bagofwordsdf_rdm_VS_37dim_rdm: M1=0.03, M2=0.03, z(17)=0.02, p=0.983.
# 37dim_rdm_VS_pc2_rdm: M1=0.03, M2=0.02, z(17)=0.15, p=0.879.
# valence_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=2.46, p=0.014. ***
# 37dim_rdm_VS_ease_rdm: M1=0.03, M2=0.01, z(17)=1.59, p=0.112.
# arousal_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=1.37, p=0.170.
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=0.50, p=0.616.
# basicemo_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=2.29, p=0.022. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.04, M2=0.03, z(17)=0.46, p=0.647.
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.00, M2=0.03, z(17)=1.81, p=0.071.
# syntax_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=1.59, p=0.112.
# tfidf_rdm_VS_37dim_rdm: M1=0.04, M2=0.03, z(17)=0.50, p=0.616.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.72, p=0.006. ***

# %%
# %autoreload
#timecourse analysis
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
vizfuncs.plottcresults(tcobjs, roilist)
