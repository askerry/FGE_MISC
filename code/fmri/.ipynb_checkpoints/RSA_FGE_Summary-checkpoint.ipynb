# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSAfinal'#"_matched_rois" #tag on the exp object
savetag='_RSAfinal'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
# %autoreload
roi_summaries={}
for roi in roilist:
    for models2show in [vizcfg.modelkeys, vizcfg.bestfeats]:
        filename='%sResultsSummary_%s.pkl' %(analdir, roi)
        rs=mum.loadpickledobject(filename)
        roi_summaries[roi]=rs
        rs.summarize_grn2models(models2show=models2show, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4], printit=False)
        rs.summarize_grn2modelsRFX(models2show=models2show,modelcolors=vizcfg.modelcolors,ylim=[-.05,.20],errorbars='bs', noiseceiling=rs.noiseceiling, printit=True)#'ws'
        rs.summarize_grnmodelcomparisonsRFX(models2show=models2show, showstats=['37appraisals_rdm'])
# Out:
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.07(0.02), p=0.000 ***
# basicemo_rdm: kendallstau(SEM)=0.04(0.01), p=0.006 ***
# valencearousal_rdm: kendallstau(SEM)=0.05(0.01), p=0.000 ***
# valence_rdm: kendallstau(SEM)=0.04(0.01), p=0.001 ***
# arousal_rdm: kendallstau(SEM)=0.05(0.01), p=0.000 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.01(0.01), p=0.319
# sentimentRNTN_rdm: kendallstau(SEM)=0.01(0.01), p=0.186
# syntax_rdm: kendallstau(SEM)=0.04(0.01), p=0.007 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), p=0.199
# tfidf_rdm: kendallstau(SEM)=0.04(0.01), p=0.002 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), p=0.000 ***
# 1stPC_rdm: kendallstau(SEM)=0.07(0.02), p=0.000 ***
# 2ndPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.051
# 3rdPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.153
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.07, M2=0.02, z(21)=2.32, p=0.020. ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.07, M2=0.03, z(21)=1.67, p=0.095.
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.07, M2=0.04, z(21)=1.67, p=0.095.
# 37appraisals_rdm_VS_valence_rdm: M1=0.07, M2=0.04, z(21)=3.07, p=0.002. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.07, M2=0.04, z(21)=1.80, p=0.072.
# arousal_rdm_VS_37appraisals_rdm: M1=0.05, M2=0.07, z(21)=0.80, p=0.426.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.07, M2=0.01, z(21)=3.07, p=0.002. ***
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.07, M2=0.02, z(21)=2.74, p=0.006. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.07, M2=0.01, z(21)=2.81, p=0.005. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.07, M2=0.04, z(21)=3.65, p=0.000. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.07, M2=0.07, z(21)=0.05, p=0.961.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=2.78, p=0.006. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.07, M2=0.01, z(21)=2.84, p=0.005. ***
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), p=0.131
# peoplefeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.009 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.263
# relevancefeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.001 ***
# pastfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.011 ***
# pleasantnessfeat_rdm: kendallstau(SEM)=0.05(0.01), p=0.000 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.01(0.01), p=0.253
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.005 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.020 ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), p=0.009 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), p=0.003 ***
# valence_rdm: kendallstau(SEM)=0.03(0.01), p=0.009 ***
# arousal_rdm: kendallstau(SEM)=0.06(0.01), p=0.000 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.02(0.01), p=0.047 ***
# sentimentRNTN_rdm: kendallstau(SEM)=0.01(0.01), p=0.354
# syntax_rdm: kendallstau(SEM)=0.03(0.01), p=0.002 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), p=0.223
# tfidf_rdm: kendallstau(SEM)=0.05(0.01), p=0.001 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), p=0.017 ***
# 1stPC_rdm: kendallstau(SEM)=0.06(0.02), p=0.002 ***
# 2ndPC_rdm: kendallstau(SEM)=0.03(0.01), p=0.017 ***
# 3rdPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.044 ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.02, z(21)=2.58, p=0.010. ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(21)=2.06, p=0.039. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.05, z(21)=1.25, p=0.211.
# 37appraisals_rdm_VS_valence_rdm: M1=0.06, M2=0.03, z(21)=3.20, p=0.001. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.03, z(21)=2.29, p=0.022. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.06, z(21)=0.28, p=0.783.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(21)=2.55, p=0.011. ***
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.06, M2=0.03, z(21)=2.13, p=0.033. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=0.01, z(21)=2.97, p=0.003. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(21)=2.97, p=0.003. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.06, M2=0.06, z(21)=0.89, p=0.372.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.87, p=0.004. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.06, M2=0.02, z(21)=2.68, p=0.007. ***
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.02), p=0.146
# peoplefeat_rdm: kendallstau(SEM)=0.06(0.01), p=0.000 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.000 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.012 ***
# relevancefeat_rdm: kendallstau(SEM)=0.05(0.01), p=0.001 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.089
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.003 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), p=0.020 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.014 ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), p=0.014 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), p=0.001 ***
# valence_rdm: kendallstau(SEM)=0.04(0.01), p=0.004 ***
# arousal_rdm: kendallstau(SEM)=0.04(0.01), p=0.003 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.01(0.01), p=0.272
# sentimentRNTN_rdm: kendallstau(SEM)=0.01(0.01), p=0.227
# syntax_rdm: kendallstau(SEM)=0.03(0.01), p=0.006 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), p=0.197
# tfidf_rdm: kendallstau(SEM)=0.03(0.02), p=0.037 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), p=0.003 ***
# 1stPC_rdm: kendallstau(SEM)=0.06(0.02), p=0.002 ***
# 2ndPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.046 ***
# 3rdPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.115
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.02, z(20)=1.79, p=0.073.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(20)=1.34, p=0.181.
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.03, z(20)=1.69, p=0.092.
# 37appraisals_rdm_VS_valence_rdm: M1=0.06, M2=0.04, z(20)=2.45, p=0.014. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.03, z(20)=1.65, p=0.099.
# arousal_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.06, z(20)=0.85, p=0.394.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(20)=2.49, p=0.013. ***
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.06, M2=0.02, z(20)=2.14, p=0.033. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=0.01, z(20)=2.73, p=0.006. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(20)=3.14, p=0.002. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.06, M2=0.06, z(20)=0.40, p=0.689.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=2.00, p=0.046. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.06, M2=0.01, z(20)=2.97, p=0.003. ***
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), p=0.188
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.115
# selfcausefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.080
# relevancefeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.003 ***
# pastfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.018 ***
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.002 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), p=0.411
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.015 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.080
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.05(0.01), p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.02(0.01), p=0.008 ***
# valencearousal_rdm: kendallstau(SEM)=0.02(0.01), p=0.002 ***
# valence_rdm: kendallstau(SEM)=0.02(0.01), p=0.005 ***
# arousal_rdm: kendallstau(SEM)=0.03(0.01), p=0.007 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.03(0.01), p=0.005 ***
# sentimentRNTN_rdm: kendallstau(SEM)=0.01(0.01), p=0.253
# syntax_rdm: kendallstau(SEM)=0.02(0.01), p=0.044 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), p=0.013 ***
# tfidf_rdm: kendallstau(SEM)=0.04(0.01), p=0.009 ***
# intensity_rdm: kendallstau(SEM)=0.02(0.01), p=0.010 ***
# 1stPC_rdm: kendallstau(SEM)=0.04(0.01), p=0.004 ***
# 2ndPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.051
# 3rdPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.070
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.05, M2=0.02, z(21)=1.61, p=0.108.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.05, M2=0.02, z(21)=2.16, p=0.031. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.05, M2=0.04, z(21)=0.37, p=0.709.
# 37appraisals_rdm_VS_valence_rdm: M1=0.05, M2=0.02, z(21)=2.68, p=0.007. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.05, M2=0.02, z(21)=2.26, p=0.024. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.05, z(21)=1.12, p=0.263.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.05, M2=0.02, z(21)=1.64, p=0.101.
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.05, M2=0.02, z(21)=2.09, p=0.036. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.05, M2=0.01, z(21)=2.35, p=0.019. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.05, M2=0.02, z(21)=2.65, p=0.008. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.05, M2=0.04, z(21)=1.38, p=0.168.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.05, M2=0.02, z(21)=2.48, p=0.013. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.05, M2=0.03, z(21)=1.51, p=0.131.
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), p=0.223
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.022 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.002 ***
# selfcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), p=0.319
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.007 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.331
# pleasantnessfeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.007 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), p=0.025 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.027 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.038 ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.08(0.02), p=0.000 ***
# basicemo_rdm: kendallstau(SEM)=0.05(0.01), p=0.001 ***
# valencearousal_rdm: kendallstau(SEM)=0.06(0.02), p=0.001 ***
# valence_rdm: kendallstau(SEM)=0.06(0.01), p=0.001 ***
# arousal_rdm: kendallstau(SEM)=0.03(0.01), p=0.013 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.01(0.01), p=0.217
# sentimentRNTN_rdm: kendallstau(SEM)=-0.01(0.01), p=0.139
# syntax_rdm: kendallstau(SEM)=0.03(0.01), p=0.009 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), p=0.018 ***
# tfidf_rdm: kendallstau(SEM)=0.02(0.01), p=0.073
# intensity_rdm: kendallstau(SEM)=0.02(0.01), p=0.054
# 1stPC_rdm: kendallstau(SEM)=0.07(0.02), p=0.000 ***
# 2ndPC_rdm: kendallstau(SEM)=0.03(0.01), p=0.050
# 3rdPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.058
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.08, M2=0.02, z(19)=3.10, p=0.002. ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.08, M2=0.02, z(19)=3.21, p=0.001. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.08, M2=0.02, z(19)=2.99, p=0.003. ***
# 37appraisals_rdm_VS_valence_rdm: M1=0.08, M2=0.06, z(19)=2.91, p=0.004. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.08, M2=0.03, z(19)=2.50, p=0.012. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.08, z(19)=2.87, p=0.004. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.08, M2=0.02, z(19)=2.39, p=0.017. ***
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.08, M2=0.03, z(19)=2.58, p=0.010. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.08, M2=-0.01, z(19)=3.43, p=0.001. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.08, M2=0.05, z(19)=3.02, p=0.002. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.08, M2=0.07, z(19)=1.61, p=0.108.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.08, M2=0.06, z(19)=2.84, p=0.005. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.08, M2=0.01, z(19)=2.80, p=0.005. ***
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=0.00(0.02), p=0.485
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.013 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.014 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.006 ***
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.003 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.131
# pleasantnessfeat_rdm: kendallstau(SEM)=0.06(0.02), p=0.001 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), p=0.022 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.02), p=0.078
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), p=0.002 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), p=0.006 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), p=0.002 ***
# valence_rdm: kendallstau(SEM)=0.03(0.01), p=0.006 ***
# arousal_rdm: kendallstau(SEM)=0.03(0.01), p=0.014 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.01(0.01), p=0.131
# sentimentRNTN_rdm: kendallstau(SEM)=-0.01(0.01), p=0.288
# syntax_rdm: kendallstau(SEM)=0.02(0.01), p=0.050
# readingease_rdm: kendallstau(SEM)=0.01(0.01), p=0.341
# tfidf_rdm: kendallstau(SEM)=0.02(0.01), p=0.058
# intensity_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# 1stPC_rdm: kendallstau(SEM)=0.05(0.02), p=0.003 ***
# 2ndPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.217
# 3rdPC_rdm: kendallstau(SEM)=0.03(0.01), p=0.010 ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.03, z(19)=1.64, p=0.100.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(19)=2.05, p=0.040. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.02, z(19)=2.17, p=0.030. ***
# 37appraisals_rdm_VS_valence_rdm: M1=0.06, M2=0.03, z(19)=2.87, p=0.004. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.02, z(19)=1.98, p=0.048. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(19)=1.83, p=0.067.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(19)=2.02, p=0.044. ***
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.06, M2=0.02, z(19)=2.20, p=0.028. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=-0.01, z(19)=2.84, p=0.005. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(19)=2.31, p=0.021. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.06, M2=0.05, z(19)=1.27, p=0.204.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=2.80, p=0.005. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.06, M2=0.01, z(19)=2.43, p=0.015. ***
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=0.00(0.01), p=0.368
# peoplefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.089
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.063
# selfcausefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.124
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.008 ***
# pastfeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.054
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.004 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), p=0.301
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.006 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.043 ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.03(0.01), p=0.035 ***
# basicemo_rdm: kendallstau(SEM)=0.01(0.01), p=0.085
# valencearousal_rdm: kendallstau(SEM)=0.02(0.01), p=0.116
# valence_rdm: kendallstau(SEM)=0.01(0.01), p=0.153
# arousal_rdm: kendallstau(SEM)=0.02(0.01), p=0.035 ***
# sentimentBoW_rdm: kendallstau(SEM)=0.02(0.01), p=0.039 ***
# sentimentRNTN_rdm: kendallstau(SEM)=-0.00(0.01), p=0.422
# syntax_rdm: kendallstau(SEM)=0.03(0.01), p=0.021 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), p=0.186
# tfidf_rdm: kendallstau(SEM)=0.05(0.01), p=0.003 ***
# intensity_rdm: kendallstau(SEM)=0.00(0.01), p=0.186
# 1stPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.143
# 2ndPC_rdm: kendallstau(SEM)=0.02(0.01), p=0.039 ***
# 3rdPC_rdm: kendallstau(SEM)=0.03(0.01), p=0.011 ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.03, M2=0.03, z(17)=0.20, p=0.845.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.03, M2=0.00, z(17)=1.98, p=0.048. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.03, M2=0.05, z(17)=1.11, p=0.267.
# 37appraisals_rdm_VS_valence_rdm: M1=0.03, M2=0.01, z(17)=2.37, p=0.018. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.03, M2=0.03, z(17)=0.46, p=0.647.
# arousal_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.03, z(17)=1.11, p=0.267.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.03, M2=0.02, z(17)=0.98, p=0.327.
# 37appraisals_rdm_VS_2ndPC_rdm: M1=0.03, M2=0.02, z(17)=0.76, p=0.446.
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.03, M2=-0.00, z(17)=1.63, p=0.102.
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.03, M2=0.01, z(17)=2.11, p=0.035. ***
# 37appraisals_rdm_VS_1stPC_rdm: M1=0.03, M2=0.02, z(17)=2.46, p=0.014. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.20, p=0.028. ***
# 37appraisals_rdm_VS_sentimentBoW_rdm: M1=0.03, M2=0.02, z(17)=0.63, p=0.528.
# one-sample test against 0
# occurredfeat_rdm: kendallstau(SEM)=-0.02(0.02), p=0.143
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), p=0.026 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.264
# selfcausefeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.405
# relevancefeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.014 ***
# pastfeat_rdm: kendallstau(SEM)=0.02(0.01), p=0.092
# pleasantnessfeat_rdm: kendallstau(SEM)=0.01(0.01), p=0.153
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), p=0.035 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.04(0.01), p=0.001 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=-0.00(0.01), p=0.491

# %%
# %autoreload
#timecourse analysis
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
vizfuncs.plottcresults(tcobjs, roilist)
