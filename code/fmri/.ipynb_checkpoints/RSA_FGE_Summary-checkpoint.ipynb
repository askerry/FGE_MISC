# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import seaborn as sns
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSAfinal'#"_matched_rois" #tag on the exp object
savetag='_RSAfinal'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
ms=sns.color_palette('GnBu_r',7)[:5]
sns.palplot(ms)
dim38=(.2,.1,.6)
sns.palplot(dim38)
best10=ms[0]
sns.palplot(best10)
pinks=[(tup[0], tup[1], tup[2], .7) for tup in sns.color_palette('YlOrRd',6)[2:]]
sns.palplot(pinks)
gns=[(tup[0], tup[1], tup[2], .7) for tup in sns.color_palette('summer',10)]
#shuffle(gns)
gns=gns[6]
sns.palplot(gns)

# %%
keys=vizcfg.modelkeys+['37appraisals_rdm']+vizcfg.bestfeats
print keys
vizcfg.modelcolors['37appraisals_rdm']=dim38
vizcfg.modelcolors['basicemo_rdm']=ms[1]
vizcfg.modelcolors['valencearousal_rdm']=ms[2]
vizcfg.modelcolors['valence_rdm']=ms[3]
vizcfg.modelcolors['arousal_rdm']=ms[4]
vizcfg.modelcolors['syntax_rdm']=pinks[0]
vizcfg.modelcolors['readingease_rdm']=pinks[1]
vizcfg.modelcolors['tfidf_rdm']=ms[3]
vizcfg.modelcolors['intensity_rdm']=pinks[2]
vizcfg.modelcolors['best10features_rdm']=ms[0]#best10
vizcfg.modelcolors['occurredfeat_rdm']=gns
vizcfg.modelcolors['peoplefeat_rdm']=gns
vizcfg.modelcolors['relationshipinfluencefeat_rdm']=gns
vizcfg.modelcolors['selfcausefeat_rdm']=gns
vizcfg.modelcolors['relevancefeat_rdm']=gns
vizcfg.modelcolors['pastfeat_rdm']=gns
vizcfg.modelcolors['pleasantnessfeat_rdm']=gns
vizcfg.modelcolors['agentcausefeat_rdm']=gns
vizcfg.modelcolors['repetitionfeat_rdm']=gns
vizcfg.modelcolors['bodilydiseasefeat_rdm']=gns
'''
vizcfg.modelcolors['occurredfeat_rdm']=gns[0]
vizcfg.modelcolors['peoplefeat_rdm']=gns[1]
vizcfg.modelcolors['relationshipinfluencefeat_rdm']=gns[2]
vizcfg.modelcolors['selfcausefeat_rdm']=gns[3]
vizcfg.modelcolors['relevancefeat_rdm']=gns[4]
vizcfg.modelcolors['pastfeat_rdm']=gns[5]
vizcfg.modelcolors['pleasantnessfeat_rdm']=gns[6]
vizcfg.modelcolors['agentcausefeat_rdm']=gns[7]
vizcfg.modelcolors['repetitionfeat_rdm']=gns[8]
vizcfg.modelcolors['bodilydiseasefeat_rdm']=gns[9]
'''
# Out:
# ['behaviorialconfs_rdm', '37appraisals_rdm', 'basicemo_rdm', 'valencearousal_rdm', 'valence_rdm', 'arousal_rdm', 'syntax_rdm', 'readingease_rdm', 'tfidf_rdm', 'intensity_rdm', '37appraisals_rdm', 'best10features_rdm', 'occurredfeat_rdm', 'peoplefeat_rdm', 'relationshipinfluencefeat_rdm', 'selfcausefeat_rdm', 'relevancefeat_rdm', 'pastfeat_rdm', 'pleasantnessfeat_rdm', 'agentcausefeat_rdm', 'repetitionfeat_rdm', 'bodilydiseasefeat_rdm']
# "\nvizcfg.modelcolors['occurredfeat_rdm']=gns[0]\nvizcfg.modelcolors['peoplefeat_rdm']=gns[1]\nvizcfg.modelcolors['relationshipinfluencefeat_rdm']=gns[2]\nvizcfg.modelcolors['selfcausefeat_rdm']=gns[3]\nvizcfg.modelcolors['relevancefeat_rdm']=gns[4]\nvizcfg.modelcolors['pastfeat_rdm']=gns[5]\nvizcfg.modelcolors['pleasantnessfeat_rdm']=gns[6]\nvizcfg.modelcolors['agentcausefeat_rdm']=gns[7]\nvizcfg.modelcolors['repetitionfeat_rdm']=gns[8]\nvizcfg.modelcolors['bodilydiseasefeat_rdm']=gns[9]\n"

# %%
finalkeyorder=['37appraisals_rdm','basicemo_rdm','valencearousal_rdm','tfidf_rdm','intensity_rdm','syntax_rdm','readingease_rdm']

# %%
vizcfg.modelkeys[1:]
# Out:
# ['37appraisals_rdm',
#  'basicemo_rdm',
#  'valencearousal_rdm',
#  'valence_rdm',
#  'arousal_rdm',
#  'syntax_rdm',
#  'readingease_rdm',
#  'tfidf_rdm',
#  'intensity_rdm']

# %%
# %autoreload
roi_summaries={}
blanks=[4, None]
for roi in roilist:
    for models2shown, models2show in enumerate([finalkeyorder, ['37appraisals_rdm']+vizcfg.bestfeats]):
    #for models2show in [vizcfg.modelkeys[1:], ['37appraisals_rdm']+vizcfg.bestfeats]:
        filename='%sResultsSummary_%s.pkl' %(analdir, roi)
        rs=mum.loadpickledobject(filename)
        roi_summaries[roi]=rs
        #rs.summarize_grn2models(models2show=models2show, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4], printit=True)
        rs.summarize_grn2modelsRFX(models2show=models2show,modelcolors=vizcfg.modelcolors,ylim=[-.05,.12],errorbars='bs', noiseceiling=rs.noiseceiling, printit=True, insertblank=blanks[models2shown])#'ws'
        rs.summarize_grnmodelcomparisonsRFX(models2show=models2show, showstats=['37appraisals_rdm'])
# Out:
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/matplotlib/font_manager.py:1236: UserWarning:
#
# findfont: Font family ['Arial'] not found. Falling back to Bitstream Vera Sans
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.07(0.02), stat(21)=3.59 p=0.000 ***
# basicemo_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.52 p=0.006 ***
# valencearousal_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.43 p=0.000 ***
# tfidf_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.94 p=0.002 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=3.39 p=0.000 ***
# syntax_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.45 p=0.007 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), stat(21)=0.84 p=0.199
# 37appraisals_rdm_VS_intensity_rdm: M1=0.07, M2=0.03, z(21)=1.67, p=0.095.
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.07, M2=0.04, z(21)=1.67, p=0.095.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.07, M2=0.04, z(21)=1.80, p=0.072.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.07, M2=0.01, z(21)=3.07, p=0.002. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.07, M2=0.04, z(21)=3.65, p=0.000. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=2.78, p=0.006. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.07(0.02), stat(21)=3.59 p=0.000 ***
# best10features_rdm: kendallstau(SEM)=0.06(0.01), stat(21)=3.55 p=0.000 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), stat(21)=1.12 p=0.131
# peoplefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.39 p=0.009 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.42 p=0.008 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.01(0.01), stat(21)=0.63 p=0.263
# relevancefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=3.04 p=0.001 ***
# pastfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.29 p=0.011 ***
# pleasantnessfeat_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.39 p=0.000 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.01(0.01), stat(21)=0.67 p=0.253
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.55 p=0.005 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.06 p=0.020 ***
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.07, M2=0.03, z(21)=2.35, p=0.019. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.07, M2=0.04, z(21)=1.67, p=0.095.
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.07, M2=0.04, z(21)=1.41, p=0.158.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.07, M2=0.03, z(21)=2.65, p=0.008. ***
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.01, M2=0.07, z(21)=3.17, p=0.002. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.07, M2=-0.01, z(21)=2.97, p=0.003. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.07, M2=0.01, z(21)=3.81, p=0.000. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.07, M2=0.06, z(21)=1.74, p=0.082.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.07, M2=0.03, z(21)=2.00, p=0.046. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.07, M2=0.05, z(21)=2.81, p=0.005. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.07, M2=0.03, z(21)=1.70, p=0.088.
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(21)=2.97 p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.35 p=0.009 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.74 p=0.003 ***
# tfidf_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.04 p=0.001 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.13 p=0.017 ***
# syntax_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.91 p=0.002 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), stat(21)=0.76 p=0.223
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(21)=2.06, p=0.039. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.05, z(21)=1.25, p=0.211.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.03, z(21)=2.29, p=0.022. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(21)=2.55, p=0.011. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(21)=2.97, p=0.003. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.87, p=0.004. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(21)=2.97 p=0.001 ***
# best10features_rdm: kendallstau(SEM)=0.06(0.02), stat(21)=2.97 p=0.001 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.02), stat(21)=1.06 p=0.146
# peoplefeat_rdm: kendallstau(SEM)=0.06(0.01), stat(21)=3.39 p=0.000 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=3.30 p=0.000 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.26 p=0.012 ***
# relevancefeat_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.23 p=0.001 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), stat(21)=1.35 p=0.089
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.74 p=0.003 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), stat(21)=2.06 p=0.020 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.42 p=0.008 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.19 p=0.014 ***
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.06, M2=0.01, z(21)=2.91, p=0.004. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.06, M2=0.05, z(21)=1.28, p=0.200.
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.06, M2=0.06, z(21)=0.41, p=0.685.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.06, M2=0.03, z(21)=1.54, p=0.123.
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.01, M2=0.06, z(21)=2.97, p=0.003. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.06, M2=-0.02, z(21)=3.13, p=0.002. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.06, M2=0.03, z(21)=2.81, p=0.005. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.06, M2=0.06, z(21)=1.22, p=0.223.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.06, M2=0.03, z(21)=2.06, p=0.039. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.06, M2=0.04, z(21)=2.74, p=0.006. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.06, M2=0.03, z(21)=2.00, p=0.046. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(20)=2.97 p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.21 p=0.014 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), stat(20)=3.22 p=0.001 ***
# tfidf_rdm: kendallstau(SEM)=0.03(0.02), stat(20)=1.79 p=0.037 ***
# intensity_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.80 p=0.003 ***
# syntax_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.52 p=0.006 ***
# readingease_rdm: kendallstau(SEM)=0.01(0.01), stat(20)=0.85 p=0.197
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(20)=1.34, p=0.181.
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.03, z(20)=1.69, p=0.092.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.03, z(20)=1.65, p=0.099.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(20)=2.49, p=0.013. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(20)=3.14, p=0.002. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=2.00, p=0.046. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(20)=2.97 p=0.001 ***
# best10features_rdm: kendallstau(SEM)=0.06(0.02), stat(20)=3.01 p=0.001 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), stat(20)=0.89 p=0.188
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.42 p=0.008 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.01(0.01), stat(20)=1.20 p=0.115
# selfcausefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(20)=1.41 p=0.080
# relevancefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(20)=2.76 p=0.003 ***
# pastfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.10 p=0.018 ***
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), stat(20)=2.83 p=0.002 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), stat(20)=0.23 p=0.411
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(20)=2.17 p=0.015 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.01(0.01), stat(20)=1.41 p=0.080
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.06, M2=0.03, z(20)=1.76, p=0.079.
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.06, M2=0.04, z(20)=1.44, p=0.149.
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.06, M2=0.03, z(20)=0.85, p=0.394.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.06, M2=0.01, z(20)=2.45, p=0.014. ***
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.01, M2=0.06, z(20)=2.80, p=0.005. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.06, M2=-0.00, z(20)=2.42, p=0.016. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.06, M2=0.02, z(20)=2.90, p=0.004. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.06, M2=0.06, z(20)=0.75, p=0.455.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.06, M2=0.01, z(20)=2.43, p=0.015. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.06, M2=0.04, z(20)=1.96, p=0.050. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.06, M2=0.03, z(20)=2.55, p=0.011. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.07 p=0.001 ***
# basicemo_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.42 p=0.008 ***
# valencearousal_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.91 p=0.002 ***
# tfidf_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.39 p=0.009 ***
# intensity_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.32 p=0.010 ***
# syntax_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=1.70 p=0.044 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.22 p=0.013 ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.05, M2=0.02, z(21)=2.16, p=0.031. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.05, M2=0.04, z(21)=0.37, p=0.709.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.05, M2=0.02, z(21)=2.26, p=0.024. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.05, M2=0.02, z(21)=1.64, p=0.101.
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.05, M2=0.02, z(21)=2.65, p=0.008. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.05, M2=0.02, z(21)=2.48, p=0.013. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.07 p=0.001 ***
# best10features_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.42 p=0.008 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.01(0.01), stat(21)=0.76 p=0.223
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.01 p=0.022 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=2.91 p=0.002 ***
# selfcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), stat(21)=0.47 p=0.319
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.45 p=0.007 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), stat(21)=0.44 p=0.331
# pleasantnessfeat_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.45 p=0.007 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), stat(21)=1.96 p=0.025 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=1.93 p=0.027 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=1.77 p=0.038 ***
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.05, M2=0.01, z(21)=2.48, p=0.013. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.05, M2=0.03, z(21)=1.38, p=0.168.
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.05, M2=0.03, z(21)=1.15, p=0.249.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.05, M2=0.02, z(21)=1.74, p=0.082.
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.01, M2=0.05, z(21)=2.91, p=0.004. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.05, M2=-0.02, z(21)=3.20, p=0.001. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.05, M2=-0.00, z(21)=3.62, p=0.000. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.05, M2=0.04, z(21)=2.00, p=0.046. ***
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.05, M2=0.04, z(21)=1.25, p=0.211.
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.05, M2=0.02, z(21)=2.71, p=0.007. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.05, M2=0.02, z(21)=1.70, p=0.088.
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.08(0.02), stat(19)=3.32 p=0.000 ***
# basicemo_rdm: kendallstau(SEM)=0.05(0.01), stat(19)=3.14 p=0.001 ***
# valencearousal_rdm: kendallstau(SEM)=0.06(0.02), stat(19)=3.29 p=0.001 ***
# tfidf_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.46 p=0.073
# intensity_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.61 p=0.054
# syntax_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.35 p=0.009 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=2.09 p=0.018 ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.08, M2=0.02, z(19)=3.21, p=0.001. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.08, M2=0.02, z(19)=2.99, p=0.003. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.08, M2=0.03, z(19)=2.50, p=0.012. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.08, M2=0.02, z(19)=2.39, p=0.017. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.08, M2=0.05, z(19)=3.02, p=0.002. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.08, M2=0.06, z(19)=2.84, p=0.005. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.08(0.02), stat(19)=3.32 p=0.000 ***
# best10features_rdm: kendallstau(SEM)=0.08(0.02), stat(19)=3.21 p=0.001 ***
# occurredfeat_rdm: kendallstau(SEM)=0.00(0.02), stat(19)=0.04 p=0.485
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.22 p=0.013 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.18 p=0.014 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(19)=2.54 p=0.006 ***
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.76 p=0.003 ***
# pastfeat_rdm: kendallstau(SEM)=0.01(0.01), stat(19)=1.12 p=0.131
# pleasantnessfeat_rdm: kendallstau(SEM)=0.06(0.02), stat(19)=3.21 p=0.001 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), stat(19)=2.02 p=0.022 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.39 p=0.008 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.02), stat(19)=1.42 p=0.078
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.08, M2=0.01, z(19)=3.62, p=0.000. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.08, M2=0.03, z(19)=3.25, p=0.001. ***
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.08, M2=0.03, z(19)=2.46, p=0.014. ***
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.08, M2=0.02, z(19)=2.73, p=0.006. ***
# occurredfeat_rdm_VS_37appraisals_rdm: M1=0.00, M2=0.08, z(19)=2.54, p=0.011. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.08, M2=-0.02, z(19)=3.14, p=0.002. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.08, M2=0.04, z(19)=3.02, p=0.002. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.08, M2=0.08, z(19)=1.57, p=0.117.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.08, M2=0.03, z(19)=2.69, p=0.007. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.08, M2=0.06, z(19)=3.06, p=0.002. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.08, M2=0.03, z(19)=3.02, p=0.002. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(19)=2.95 p=0.002 ***
# basicemo_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.54 p=0.006 ***
# valencearousal_rdm: kendallstau(SEM)=0.04(0.01), stat(19)=2.87 p=0.002 ***
# tfidf_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.57 p=0.058
# intensity_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.39 p=0.008 ***
# syntax_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.64 p=0.050
# readingease_rdm: kendallstau(SEM)=0.01(0.01), stat(19)=0.41 p=0.341
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(19)=2.05, p=0.040. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.06, M2=0.02, z(19)=2.17, p=0.030. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.02, z(19)=1.98, p=0.048. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.06, M2=0.01, z(19)=2.02, p=0.044. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.06, M2=0.03, z(19)=2.31, p=0.021. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=2.80, p=0.005. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.06(0.02), stat(19)=2.95 p=0.002 ***
# best10features_rdm: kendallstau(SEM)=0.05(0.02), stat(19)=2.61 p=0.004 ***
# occurredfeat_rdm: kendallstau(SEM)=0.00(0.01), stat(19)=0.34 p=0.368
# peoplefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.34 p=0.089
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.53 p=0.063
# selfcausefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.16 p=0.124
# relevancefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.39 p=0.008 ***
# pastfeat_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.61 p=0.054
# pleasantnessfeat_rdm: kendallstau(SEM)=0.04(0.01), stat(19)=2.61 p=0.004 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.00(0.01), stat(19)=0.52 p=0.301
# repetitionfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(19)=2.50 p=0.006 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(19)=1.72 p=0.043 ***
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.06, M2=0.02, z(19)=2.17, p=0.030. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.06, M2=0.03, z(19)=2.31, p=0.021. ***
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.06, M2=0.02, z(19)=1.72, p=0.086.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.06, M2=0.02, z(19)=1.94, p=0.052.
# occurredfeat_rdm_VS_37appraisals_rdm: M1=0.00, M2=0.06, z(19)=2.20, p=0.028. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.06, M2=-0.00, z(19)=2.45, p=0.014. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.06, M2=0.02, z(19)=2.50, p=0.012. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.06, M2=0.05, z(19)=1.27, p=0.204.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.06, M2=0.02, z(19)=2.02, p=0.044. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.06, M2=0.04, z(19)=2.58, p=0.010. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.06, M2=0.03, z(19)=2.13, p=0.033. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.03(0.01), stat(17)=1.81 p=0.035 ***
# basicemo_rdm: kendallstau(SEM)=0.01(0.01), stat(17)=1.37 p=0.085
# valencearousal_rdm: kendallstau(SEM)=0.02(0.01), stat(17)=1.20 p=0.116
# tfidf_rdm: kendallstau(SEM)=0.05(0.01), stat(17)=2.72 p=0.003 ***
# intensity_rdm: kendallstau(SEM)=0.00(0.01), stat(17)=0.89 p=0.186
# syntax_rdm: kendallstau(SEM)=0.03(0.01), stat(17)=2.03 p=0.021 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), stat(17)=0.89 p=0.186
# 37appraisals_rdm_VS_intensity_rdm: M1=0.03, M2=0.00, z(17)=1.98, p=0.048. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.03, M2=0.05, z(17)=1.11, p=0.267.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.03, M2=0.03, z(17)=0.46, p=0.647.
# 37appraisals_rdm_VS_readingease_rdm: M1=0.03, M2=0.02, z(17)=0.98, p=0.327.
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.03, M2=0.01, z(17)=2.11, p=0.035. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.20, p=0.028. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.03(0.01), stat(17)=1.81 p=0.035 ***
# best10features_rdm: kendallstau(SEM)=0.03(0.01), stat(17)=1.76 p=0.039 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.02(0.02), stat(17)=1.07 p=0.143
# peoplefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(17)=1.94 p=0.026 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(17)=0.63 p=0.264
# selfcausefeat_rdm: kendallstau(SEM)=0.01(0.01), stat(17)=0.24 p=0.405
# relevancefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(17)=2.20 p=0.014 ***
# pastfeat_rdm: kendallstau(SEM)=0.02(0.01), stat(17)=1.33 p=0.092
# pleasantnessfeat_rdm: kendallstau(SEM)=0.01(0.01), stat(17)=1.02 p=0.153
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), stat(17)=1.81 p=0.035 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.04(0.01), stat(17)=3.29 p=0.001 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=-0.00(0.01), stat(17)=0.02 p=0.491
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.03, M2=0.02, z(17)=0.94, p=0.349.
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.03, M2=0.02, z(17)=0.98, p=0.327.
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.03, M2=0.03, z(17)=0.59, p=0.557.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.03, M2=-0.00, z(17)=1.55, p=0.122.
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.02, M2=0.03, z(17)=1.59, p=0.112.
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.03, M2=-0.02, z(17)=2.37, p=0.018. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.03, M2=0.01, z(17)=2.33, p=0.020. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.03, M2=0.03, z(17)=0.89, p=0.372.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.03, M2=0.02, z(17)=0.81, p=0.420.
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.03, M2=0.01, z(17)=2.68, p=0.007. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.03, M2=0.04, z(17)=0.89, p=0.372.
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.09(0.02), stat(21)=3.68 p=0.000 ***
# basicemo_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.00 p=0.001 ***
# valencearousal_rdm: kendallstau(SEM)=0.06(0.01), stat(21)=3.62 p=0.000 ***
# tfidf_rdm: kendallstau(SEM)=0.06(0.01), stat(21)=3.10 p=0.001 ***
# intensity_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=3.26 p=0.001 ***
# syntax_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=3.04 p=0.001 ***
# readingease_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=1.90 p=0.029 ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.09, M2=0.04, z(21)=2.84, p=0.005. ***
# 37appraisals_rdm_VS_tfidf_rdm: M1=0.09, M2=0.06, z(21)=1.93, p=0.053.
# 37appraisals_rdm_VS_syntax_rdm: M1=0.09, M2=0.04, z(21)=2.81, p=0.005. ***
# 37appraisals_rdm_VS_readingease_rdm: M1=0.09, M2=0.02, z(21)=3.00, p=0.003. ***
# 37appraisals_rdm_VS_basicemo_rdm: M1=0.09, M2=0.05, z(21)=3.62, p=0.000. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.09, M2=0.06, z(21)=3.17, p=0.002. ***
# one-sample test against 0
# 37appraisals_rdm: kendallstau(SEM)=0.09(0.02), stat(21)=3.68 p=0.000 ***
# best10features_rdm: kendallstau(SEM)=0.08(0.02), stat(21)=3.68 p=0.000 ***
# occurredfeat_rdm: kendallstau(SEM)=-0.02(0.02), stat(21)=1.41 p=0.079
# peoplefeat_rdm: kendallstau(SEM)=0.05(0.02), stat(21)=2.91 p=0.002 ***
# relationshipinfluencefeat_rdm: kendallstau(SEM)=0.04(0.01), stat(21)=3.04 p=0.001 ***
# selfcausefeat_rdm: kendallstau(SEM)=0.02(0.01), stat(21)=2.39 p=0.009 ***
# relevancefeat_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.59 p=0.000 ***
# pastfeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.48 p=0.007 ***
# pleasantnessfeat_rdm: kendallstau(SEM)=0.06(0.01), stat(21)=3.43 p=0.000 ***
# agentcausefeat_rdm: kendallstau(SEM)=-0.02(0.01), stat(21)=1.67 p=0.047 ***
# repetitionfeat_rdm: kendallstau(SEM)=0.05(0.01), stat(21)=3.68 p=0.000 ***
# bodilydiseasefeat_rdm: kendallstau(SEM)=0.03(0.01), stat(21)=2.29 p=0.011 ***
# 37appraisals_rdm_VS_pastfeat_rdm: M1=0.09, M2=0.03, z(21)=3.30, p=0.001. ***
# 37appraisals_rdm_VS_relevancefeat_rdm: M1=0.09, M2=0.05, z(21)=2.58, p=0.010. ***
# 37appraisals_rdm_VS_peoplefeat_rdm: M1=0.09, M2=0.05, z(21)=1.90, p=0.058.
# 37appraisals_rdm_VS_bodilydiseasefeat_rdm: M1=0.09, M2=0.03, z(21)=3.10, p=0.002. ***
# occurredfeat_rdm_VS_37appraisals_rdm: M1=-0.02, M2=0.09, z(21)=3.36, p=0.001. ***
# 37appraisals_rdm_VS_agentcausefeat_rdm: M1=0.09, M2=-0.02, z(21)=3.49, p=0.000. ***
# 37appraisals_rdm_VS_selfcausefeat_rdm: M1=0.09, M2=0.02, z(21)=3.55, p=0.000. ***
# 37appraisals_rdm_VS_best10features_rdm: M1=0.09, M2=0.08, z(21)=1.87, p=0.062.
# 37appraisals_rdm_VS_relationshipinfluencefeat_rdm: M1=0.09, M2=0.04, z(21)=2.32, p=0.020. ***
# 37appraisals_rdm_VS_pleasantnessfeat_rdm: M1=0.09, M2=0.06, z(21)=3.55, p=0.000. ***
# 37appraisals_rdm_VS_repetitionfeat_rdm: M1=0.09, M2=0.05, z(21)=2.55, p=0.011. ***

# %%
roi_summaries['PC_tomloc'].noiseceiling
# Out:
# (0.055264297106402377, 0.16400432900432904)

# %%
gns=[(tup[0], tup[1], tup[2], .5) for tup in sns.color_palette('Set1',10)]
gns[9]=[.6,.9,.1,.5]
sns.palplot(gns)
vizcfg.modelcolors['occurredfeat_rdm']=gns[0]
vizcfg.modelcolors['peoplefeat_rdm']=gns[1]
vizcfg.modelcolors['relationshipinfluencefeat_rdm']=gns[2]
vizcfg.modelcolors['selfcausefeat_rdm']=gns[3]
vizcfg.modelcolors['relevancefeat_rdm']=gns[4]
vizcfg.modelcolors['pastfeat_rdm']=gns[5]
vizcfg.modelcolors['pleasantnessfeat_rdm']=gns[6]
vizcfg.modelcolors['agentcausefeat_rdm']=gns[7]
vizcfg.modelcolors['repetitionfeat_rdm']=gns[8]
vizcfg.modelcolors['bodilydiseasefeat_rdm']=gns[9]

# %%
# %autoreload
#timecourse analysis
comparisons=[vizcfg.modelkeys[0:8], vizcfg.bestfeats]
comparisons=[vizcfg.modelkeys[1:], ['37appraisals_rdm']+vizcfg.bestfeats]
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
for c in comparisons:
    vizfuncs.plottcresults(tcobjs, roilist, models2show=c, colordict=vizcfg.modelcolors)
