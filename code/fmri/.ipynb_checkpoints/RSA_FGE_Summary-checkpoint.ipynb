# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSA'#"_matched_rois" #tag on the exp object
savetag='_RSA'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
# %autoreload
roi_summaries={}
for roi in roilist:
    filename='%sResultsSummary_%s.pkl' %(analdir, roi)
    rs=mum.loadpickledobject(filename)
    roi_summaries[roi]=rs
    rs.summarize_grn2models(models2show=vizcfg.modelkeys, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4])
    rs.summarize_grn2modelsRFX(models2show=vizcfg.modelkeys,modelcolors=vizcfg.modelcolors,ylim=[-.05,.20],errorbars='bs', noiseceiling=rs.noiseceiling)#'ws'
    rs.summarize_grnmodelcomparisonsRFX(models2show=vizcfg.modelkeys, showstats=['37dim_rdm'])
# Out:
# 37dim_rdm: corr(SEM)=0.26(0.08), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.15(0.01), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.17(0.02), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.17(0.04), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.14(0.06), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.09(0.06), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.05(0.01), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.000
# cosinesim_rdm: corr(SEM)=-0.01(0.03), p(permutation test)=0.333
# intensity_rdm: corr(SEM)=0.12(0.04), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.55, p=0.011. ***
# intensity_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=1.80, p=0.072.
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.23, p=0.001. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.59, p=0.000. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.01, M2=0.07, z(21)=3.05, p=0.002. ***
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.39, p=0.017. ***
# cosinesim_rdm_VS_37dim_rdm: M1=-0.00, M2=0.07, z(21)=2.45, p=0.014. ***
# arousal_rdm_VS_37dim_rdm: M1=0.05, M2=0.07, z(21)=0.96, p=0.338.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=2.91, p=0.004. ***
# 37dim_rdm: corr(SEM)=0.24(0.11), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.05), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.04), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.20(0.04), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.10(0.05), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.10(0.01), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.06(0.06), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.03(0.06), p(permutation test)=0.333
# cosinesim_rdm: corr(SEM)=-0.06(0.08), p(permutation test)=0.333
# intensity_rdm: corr(SEM)=0.12(0.08), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(21)=2.32, p=0.020. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=2.06, p=0.039. ***
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=3.30, p=0.001. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=2.78, p=0.006. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(21)=2.91, p=0.004. ***
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(21)=2.19, p=0.028. ***
# cosinesim_rdm_VS_37dim_rdm: M1=-0.02, M2=0.06, z(21)=2.35, p=0.019. ***
# arousal_rdm_VS_37dim_rdm: M1=0.06, M2=0.06, z(21)=0.47, p=0.638.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.79, p=0.005. ***
# 37dim_rdm: corr(SEM)=0.21(0.07), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.11(0.05), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.05), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.16(0.09), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.07), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.09(0.03), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.10(0.01), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.03(0.12), p(permutation test)=0.000
# cosinesim_rdm: corr(SEM)=0.02(0.02), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.02), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=2.17, p=0.030. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=1.42, p=0.156.
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=2.31, p=0.021. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=3.15, p=0.002. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(20)=2.87, p=0.004. ***
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(20)=1.82, p=0.068.
# cosinesim_rdm_VS_37dim_rdm: M1=-0.00, M2=0.06, z(20)=1.79, p=0.073.
# arousal_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=1.06, p=0.289.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=2.07, p=0.039. ***
# 37dim_rdm: corr(SEM)=0.17(0.01), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.08(0.03), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.09(0.06), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.12(0.08), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.06(0.03), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.333
# cohmetrix_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.000
# cosinesim_rdm: corr(SEM)=-0.08(0.06), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.09(0.03), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=1.70, p=0.088.
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=2.13, p=0.033. ***
# valence_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=3.00, p=0.003. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=2.71, p=0.007. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=1.83, p=0.067.
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.05, z(21)=1.57, p=0.115.
# cosinesim_rdm_VS_37dim_rdm: M1=-0.02, M2=0.05, z(21)=2.58, p=0.010. ***
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.05, z(21)=1.38, p=0.168.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.05, M2=0.02, z(21)=2.68, p=0.007. ***
# 37dim_rdm: corr(SEM)=0.29(0.07), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.19(0.04), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.20(0.01), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.01), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.19(0.06), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.08(0.09), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.00(0.08), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.11(0.02), p(permutation test)=0.000
# cosinesim_rdm: corr(SEM)=0.00(0.08), p(permutation test)=0.333
# intensity_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=-0.00, M2=0.09, z(19)=3.17, p=0.002. ***
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.09, z(19)=3.25, p=0.001. ***
# valence_rdm_VS_37dim_rdm: M1=0.06, M2=0.09, z(19)=2.99, p=0.003. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.06, M2=0.09, z(19)=3.25, p=0.001. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.03, M2=0.09, z(19)=2.69, p=0.007. ***
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.09, z(19)=2.61, p=0.009. ***
# cosinesim_rdm_VS_37dim_rdm: M1=-0.01, M2=0.09, z(19)=2.84, p=0.005. ***
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.09, z(19)=3.02, p=0.002. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.09, M2=0.06, z(19)=2.99, p=0.003. ***
# 37dim_rdm: corr(SEM)=0.21(0.03), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.03), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.14(0.02), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.11(0.04), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.04), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.13(0.04), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=0.02(0.05), p(permutation test)=0.000
# cohmetrix_rdm: corr(SEM)=0.05(0.08), p(permutation test)=0.333
# cosinesim_rdm: corr(SEM)=0.04(0.01), p(permutation test)=0.333
# intensity_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.00, M2=0.06, z(19)=2.54, p=0.011. ***
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=2.02, p=0.044. ***
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=2.76, p=0.006. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(19)=2.31, p=0.021. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(19)=1.98, p=0.048. ***
# naivebayes_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=1.61, p=0.108.
# cosinesim_rdm_VS_37dim_rdm: M1=0.00, M2=0.06, z(19)=1.94, p=0.052.
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=1.83, p=0.067.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=2.87, p=0.004. ***
# 37dim_rdm: corr(SEM)=0.12(0.02), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.05(0.04), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.333
# valence_rdm: corr(SEM)=0.04(0.03), p(permutation test)=0.000
# naivebayes_rdm: corr(SEM)=0.07(0.00), p(permutation test)=0.000
# dlsentiment_rdm: corr(SEM)=-0.00(0.05), p(permutation test)=0.333
# cohmetrix_rdm: corr(SEM)=0.06(0.04), p(permutation test)=0.000
# cosinesim_rdm: corr(SEM)=-0.03(0.04), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.05(0.02), p(permutation test)=0.000
# dlsentiment_rdm_VS_37dim_rdm: M1=0.00, M2=0.03, z(17)=1.76, p=0.078.
# intensity_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=1.72, p=0.085.
# valence_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=2.20, p=0.028. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=2.20, p=0.028. ***
# cohmetrix_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=0.54, p=0.586.
# naivebayes_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=0.72, p=0.472.
# cosinesim_rdm_VS_37dim_rdm: M1=-0.01, M2=0.03, z(17)=1.46, p=0.145.
# arousal_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=1.15, p=0.248.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.42, p=0.016. ***

# %%
# %autoreload
#timecourse analysis
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
vizfuncs.plottcresults(tcobjs, roilist)
