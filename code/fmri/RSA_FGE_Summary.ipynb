# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSA'#"_matched_rois" #tag on the exp object
savetag='_RSA'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
# %autoreload
roi_summaries={}
for roi in roilist:
    filename='%sResultsSummary_%s.pkl' %(analdir, roi)
    rs=mum.loadpickledobject(filename)
    roi_summaries[roi]=rs
    rs.summarize_grn2models(models2show=vizcfg.modelkeys, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4])
    rs.summarize_grn2modelsRFX(models2show=vizcfg.modelkeys,modelcolors=vizcfg.modelcolors,ylim=[-.05,.20],errorbars='bs', noiseceiling=rs.noiseceiling)#'ws'
    rs.summarize_grnmodelcomparisonsRFX(models2show=vizcfg.modelkeys, showstats=['37appraisals_rdm'])
# Out:
# 37appraisals_rdm: corr(SEM)=0.26(0.12), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.14(0.11), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.18(0.06), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.15(0.05), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.17(0.06), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.04(0.13), p(permutation test)=0.333
# sentimentRNTN_rdm: corr(SEM)=0.06(0.02), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.07(0.06), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.03(0.01), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.13(0.04), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.00), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.24(0.04), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.10(0.05), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.07, z(21)=3.51, p=0.000. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.07, M2=0.01, z(21)=2.97, p=0.003. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.05, M2=0.07, z(21)=0.83, p=0.408.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=2.84, p=0.004. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.07, z(21)=3.00, p=0.003. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.07, M2=0.02, z(21)=2.65, p=0.008. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.07, z(21)=2.58, p=0.010. ***
# readingease_rdm_VS_37appraisals_rdm: M1=0.00, M2=0.07, z(21)=3.13, p=0.002. ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.07, M2=0.03, z(21)=2.39, p=0.017. ***
# tfidf_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.07, z(21)=2.00, p=0.046. ***
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.07, z(21)=3.04, p=0.002. ***
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.07, z(21)=0.57, p=0.570.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.07, M2=0.04, z(21)=1.74, p=0.082.
# 37appraisals_rdm: corr(SEM)=0.24(0.10), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.16(0.06), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.11(0.05), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.20(0.01), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.11(0.14), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.06(0.03), p(permutation test)=0.333
# syntax_rdm: corr(SEM)=0.00(0.06), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.04(0.02), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.12(0.07), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.13(0.05), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.20(0.03), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(21)=2.84, p=0.005. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=0.01, z(21)=2.58, p=0.010. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.06, z(21)=0.41, p=0.685.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.74, p=0.006. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(21)=3.20, p=0.001. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.00, z(21)=3.04, p=0.002. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(21)=1.90, p=0.058.
# readingease_rdm_VS_37appraisals_rdm: M1=0.00, M2=0.06, z(21)=2.48, p=0.013. ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.02, z(21)=2.19, p=0.028. ***
# tfidf_rdm_VS_37appraisals_rdm: M1=0.05, M2=0.06, z(21)=1.38, p=0.168.
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(21)=2.09, p=0.036. ***
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.06, z(21)=1.18, p=0.236.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(21)=1.93, p=0.053.
# 37appraisals_rdm: corr(SEM)=0.22(0.10), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.11(0.08), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.16(0.05), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.03), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.16(0.06), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.03(0.15), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.07(0.05), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=0.06(0.04), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.05(0.00), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.08(0.10), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.02), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.20(0.04), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.07(0.06), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.09(0.01), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(20)=3.28, p=0.001. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=0.01, z(20)=2.07, p=0.039. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.06, z(20)=1.09, p=0.274.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=1.93, p=0.054.
# valence_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.06, z(20)=2.45, p=0.014. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.01, z(20)=2.52, p=0.012. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.06, z(20)=2.31, p=0.021. ***
# readingease_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.06, z(20)=2.31, p=0.021. ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.02, z(20)=1.58, p=0.114.
# tfidf_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.06, z(20)=2.52, p=0.012. ***
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.06, z(20)=2.87, p=0.004. ***
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.06, z(20)=0.43, p=0.664.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(20)=1.44, p=0.149.
# 37appraisals_rdm: corr(SEM)=0.17(0.07), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.09(0.03), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.06(0.01), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.12(0.01), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.14(0.10), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.06(0.00), p(permutation test)=0.000
# syntax_rdm: corr(SEM)=-0.02(0.03), p(permutation test)=0.333
# readingease_rdm: corr(SEM)=0.07(0.01), p(permutation test)=0.000
# tfidf_rdm: corr(SEM)=0.14(0.08), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.13(0.07), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.10(0.03), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.05, z(21)=2.37, p=0.018. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.05, M2=0.02, z(21)=1.74, p=0.082.
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.05, z(21)=1.15, p=0.249.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.05, M2=0.02, z(21)=2.35, p=0.019. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.05, z(21)=2.61, p=0.009. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.05, M2=0.00, z(21)=2.13, p=0.033. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.05, z(21)=2.19, p=0.028. ***
# readingease_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.05, z(21)=1.61, p=0.108.
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.05, M2=0.02, z(21)=1.48, p=0.140.
# tfidf_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.05, z(21)=0.24, p=0.808.
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.05, z(21)=0.54, p=0.592.
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.05, z(21)=1.57, p=0.115.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.05, M2=0.02, z(21)=1.96, p=0.050. ***
# 37appraisals_rdm: corr(SEM)=0.28(0.04), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.20(0.06), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.20(0.07), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.18(0.01), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.06), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.09(0.12), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=0.00(0.02), p(permutation test)=0.333
# syntax_rdm: corr(SEM)=0.11(0.09), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.07(0.03), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.08(0.02), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.23(0.06), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.08(0.02), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.08, z(19)=2.87, p=0.004. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.08, M2=-0.00, z(19)=3.25, p=0.001. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.08, z(19)=3.06, p=0.002. ***
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.08, M2=0.06, z(19)=2.84, p=0.005. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.06, M2=0.08, z(19)=2.95, p=0.003. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.08, M2=0.03, z(19)=2.73, p=0.006. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.08, z(19)=2.80, p=0.005. ***
# readingease_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.08, z(19)=3.02, p=0.002. ***
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.08, M2=0.02, z(19)=2.87, p=0.004. ***
# tfidf_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.08, z(19)=3.17, p=0.002. ***
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.08, z(19)=2.58, p=0.010. ***
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.07, M2=0.08, z(19)=2.28, p=0.023. ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.08, M2=0.02, z(19)=3.17, p=0.002. ***
# 37appraisals_rdm: corr(SEM)=0.21(0.06), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.08), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.06), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.02), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.11(0.04), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.08(0.09), p(permutation test)=0.333
# sentimentRNTN_rdm: corr(SEM)=0.04(0.01), p(permutation test)=0.333
# syntax_rdm: corr(SEM)=0.07(0.07), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.06(0.04), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.06(0.05), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.11(0.02), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.16(0.02), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.09(0.02), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.11(0.04), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.06, z(19)=2.05, p=0.040. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.06, M2=0.01, z(19)=2.24, p=0.025. ***
# arousal_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(19)=1.83, p=0.067.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=2.76, p=0.006. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.03, M2=0.06, z(19)=2.87, p=0.004. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.06, M2=0.02, z(19)=2.02, p=0.044. ***
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.06, z(19)=1.98, p=0.048. ***
# readingease_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.06, z(19)=1.68, p=0.093.
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.06, M2=0.03, z(19)=1.49, p=0.135.
# tfidf_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.06, z(19)=2.20, p=0.028. ***
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.06, z(19)=2.28, p=0.023. ***
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.05, M2=0.06, z(19)=1.87, p=0.062.
# 37appraisals_rdm_VS_intensity_rdm: M1=0.06, M2=0.03, z(19)=2.05, p=0.040. ***
# 37appraisals_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.05(0.07), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.05(0.02), p(permutation test)=0.333
# valence_rdm: corr(SEM)=0.04(0.06), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.01), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.09(0.09), p(permutation test)=0.333
# sentimentRNTN_rdm: corr(SEM)=0.02(0.07), p(permutation test)=0.333
# syntax_rdm: corr(SEM)=0.07(0.01), p(permutation test)=0.000
# readingease_rdm: corr(SEM)=0.03(0.04), p(permutation test)=0.333
# tfidf_rdm: corr(SEM)=0.13(0.07), p(permutation test)=0.000
# intensity_rdm: corr(SEM)=0.06(0.03), p(permutation test)=0.000
# 1stPC_rdm: corr(SEM)=0.05(0.03), p(permutation test)=0.000
# 2ndPC_rdm: corr(SEM)=0.07(0.08), p(permutation test)=0.000
# 3rdPC_rdm: corr(SEM)=0.12(0.03), p(permutation test)=0.000
# basicemo_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.03, z(17)=1.98, p=0.048. ***
# 37appraisals_rdm_VS_sentimentRNTN_rdm: M1=0.03, M2=0.01, z(17)=1.20, p=0.231.
# arousal_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.03, z(17)=1.20, p=0.231.
# 37appraisals_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.16, p=0.031. ***
# valence_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.03, z(17)=2.33, p=0.020. ***
# 37appraisals_rdm_VS_syntax_rdm: M1=0.03, M2=0.02, z(17)=0.50, p=0.616.
# 2ndPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.03, z(17)=1.07, p=0.286.
# readingease_rdm_VS_37appraisals_rdm: M1=0.01, M2=0.03, z(17)=1.33, p=0.184.
# 37appraisals_rdm_VS_3rdPC_rdm: M1=0.03, M2=0.03, z(17)=0.11, p=0.913.
# tfidf_rdm_VS_37appraisals_rdm: M1=0.04, M2=0.03, z(17)=0.72, p=0.472.
# sentimentBoW_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.03, z(17)=0.76, p=0.446.
# 1stPC_rdm_VS_37appraisals_rdm: M1=0.02, M2=0.03, z(17)=2.72, p=0.006. ***
# 37appraisals_rdm_VS_intensity_rdm: M1=0.03, M2=0.01, z(17)=1.63, p=0.102.

# %%
# %autoreload
#timecourse analysis
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
vizfuncs.plottcresults(tcobjs, roilist)

# %%
rs.grn2modelsRFX
# Out:
# {'37dim_confs_item': {'RFX_SEM': 0.012268860567968928,
#   'RFX_WSSEM': 0.0070822635430949328,
#   'RFX_pval': 0.029068393674855187,
#   'corr': 0.026929824561403502,
#   'df': 17,
#   'stat': 1.8946650760843076},
#  '37dim_rdm': {'RFX_SEM': 0.014352369337221664,
#   'RFX_WSSEM': 0.0091930110672969398,
#   'RFX_pval': 0.035354660239343118,
#   'corr': 0.033152325257588412,
#   'df': 17,
#   'stat': 1.8073397586837701},
#  'NDEconfmat_confs_item': {'RFX_SEM': 0.0062523929339754411,
#   'RFX_WSSEM': 0.0067276771288623874,
#   'RFX_pval': 0.0026553865526970609,
#   'corr': 0.021154274575327214,
#   'df': 17,
#   'stat': 2.7875532153884066},
#  'NDEconfmat_raw': {'RFX_SEM': 0.011111811302447231,
#   'RFX_WSSEM': 0.0089413961948593672,
#   'RFX_pval': 0.011115619143009622,
#   'corr': 0.026601225285435817,
#   'df': 17,
#   'stat': 2.2863936706240464},
#  'NDEconfmat_rdm': {'RFX_SEM': 0.017290854442325733,
#   'RFX_WSSEM': 0.015599155128991673,
#   'RFX_pval': 0.11552961497672648,
#   'corr': 0.020971874129768867,
#   'df': 17,
#   'stat': 1.197634779850691},
#  'arousal_confs_item': {'RFX_SEM': 0.010708007300692629,
#   'RFX_WSSEM': 0.011208397707290166,
#   'RFX_pval': 0.35562492526562939,
#   'corr': 0.0077499303815093297,
#   'df': 17,
#   'stat': 0.37017802286294083},
#  'arousal_rdm': {'RFX_SEM': 0.0098859558212217626,
#   'RFX_WSSEM': 0.0083900410815083357,
#   'RFX_pval': 0.16357193727494607,
#   'corr': 0.015196324143692565,
#   'df': 17,
#   'stat': 0.97988300169601994},
#  'bagofwordsdf_confs_item': {'RFX_SEM': 0.01227534890660994,
#   'RFX_WSSEM': 0.01032135183145127,
#   'RFX_pval': 0.021428982888300311,
#   'corr': 0.02763157894736842,
#   'df': 17,
#   'stat': 2.025091536838441},
#  'bagofwordsdf_rdm': {'RFX_SEM': 0.014789432110288219,
#   'RFX_WSSEM': 0.013908717842036436,
#   'RFX_pval': 0.02631217092767547,
#   'corr': 0.031420217209690897,
#   'df': 17,
#   'stat': 1.9379908255765728},
#  'basicemo_confs_item': {'RFX_SEM': 0.010350859173842956,
#   'RFX_WSSEM': 0.0080077358057935189,
#   'RFX_pval': 0.078477594311313278,
#   'corr': 0.018235867446393758,
#   'df': 17,
#   'stat': 1.4153865580053622},
#  'basicemo_rdm': {'RFX_SEM': 0.010728960092304325,
#   'RFX_WSSEM': 0.0065711870464348343,
#   'RFX_pval': 0.078477594311313278,
#   'corr': 0.014614313561681981,
#   'df': 17,
#   'stat': 1.4153865580053622},
#  'cohmetrix_confs_item': {'RFX_SEM': 0.011410570944341478,
#   'RFX_WSSEM': 0.011408042693485176,
#   'RFX_pval': 0.43942537932078896,
#   'corr': -0.0015176830966304638,
#   'df': 17,
#   'stat': 0.15242624470826976},
#  'cohmetrix_rdm': {'RFX_SEM': 0.012658721310894395,
#   'RFX_WSSEM': 0.011299016267880888,
#   'RFX_pval': 0.0069353404288854566,
#   'corr': 0.038345864661654128,
#   'df': 17,
#   'stat': 2.4605950931477834},
#  'ease_confs_item': {'RFX_SEM': 0.011764735535205876,
#   'RFX_WSSEM': 0.012621016878325193,
#   'RFX_pval': 0.24982818982167099,
#   'corr': -0.010692007797270954,
#   'df': 17,
#   'stat': 0.67503051227948041},
#  'ease_rdm': {'RFX_SEM': 0.01148867711371934,
#   'RFX_WSSEM': 0.010590859628951281,
#   'RFX_pval': 0.3082457054968159,
#   'corr': 0.0092286271233639663,
#   'df': 17,
#   'stat': 0.50082908975574347},
#  'explicits_confs_item': {'RFX_SEM': 0.0088459796486335916,
#   'RFX_WSSEM': 0.005798862094396345,
#   'RFX_pval': 0.032092681613819139,
#   'corr': 0.017639933166248956,
#   'df': 17,
#   'stat': 1.8508901143147043},
#  'explicits_rdm': {'RFX_SEM': 0.012011430836040306,
#   'RFX_WSSEM': 0.00730207176191196,
#   'RFX_pval': 0.10726868236025366,
#   'corr': 0.016427179058758005,
#   'df': 17,
#   'stat': 1.2411851354816252},
#  'intensity_confs_item': {'RFX_SEM': 0.0097603396558534235,
#   'RFX_WSSEM': 0.0091539433933302636,
#   'RFX_pval': 0.45665046533460463,
#   'corr': 0.0018072960178223338,
#   'df': 17,
#   'stat': 0.10887588907733554},
#  'intensity_rdm': {'RFX_SEM': 0.0090298135446716873,
#   'RFX_WSSEM': 0.0082555837793736233,
#   'RFX_pval': 0.19787612332887661,
#   'corr': 0.0049317738791422993,
#   'df': 17,
#   'stat': 0.84923193480321724},
#  'pc0_confs_item': {'RFX_SEM': 0.012879609019409797,
#   'RFX_WSSEM': 0.0085026563044096944,
#   'RFX_pval': 0.055963854059512222,
#   'corr': 0.021733500417710945,
#   'df': 17,
#   'stat': 1.5895879805290989},
#  'pc0_rdm': {'RFX_SEM': 0.012629193626171265,
#   'RFX_WSSEM': 0.0080168117950627504,
#   'RFX_pval': 0.17455097232136219,
#   'corr': 0.016730715678084099,
#   'df': 17,
#   'stat': 0.93633264606508571},
#  'pc1_confs_item': {'RFX_SEM': 0.0087750839436747281,
#   'RFX_WSSEM': 0.0093700227004959533,
#   'RFX_pval': 0.40534849842988596,
#   'corr': -0.00048593706488443266,
#   'df': 17,
#   'stat': 0.23952695597013821},
#  'pc1_rdm': {'RFX_SEM': 0.0092866415218779991,
#   'RFX_WSSEM': 0.0090622595235264908,
#   'RFX_pval': 0.066485656664433124,
#   'corr': 0.017245892509050405,
#   'df': 17,
#   'stat': 1.5024872692672304},
#  'pc2_confs_item': {'RFX_SEM': 0.0090029217233234416,
#   'RFX_WSSEM': 0.0083405827852297606,
#   'RFX_pval': 0.16357193727494607,
#   'corr': 0.0099331662489557226,
#   'df': 17,
#   'stat': 0.97988300169601994},
#  'pc2_rdm': {'RFX_SEM': 0.010101980874803702,
#   'RFX_WSSEM': 0.0075312085726891333,
#   'RFX_pval': 0.021428982888300311,
#   'corr': 0.024697855750487326,
#   'df': 17,
#   'stat': 2.025091536838441},
#  'sentimentBoW_confs_item': {'RFX_SEM': 0.011984044936999637,
#   'RFX_WSSEM': 0.014336006037256791,
#   'RFX_pval': 0.18598688598233426,
#   'corr': 0.011198830409356725,
#   'df': 17,
#   'stat': 0.89278229043415147},
#  'sentimentBoW_rdm': {'RFX_SEM': 0.012492040600557685,
#   'RFX_WSSEM': 0.012462996221843756,
#   'RFX_pval': 0.085057217250465167,
#   'corr': 0.018031189083820662,
#   'df': 17,
#   'stat': 1.3718362023744279},
#  'sentimentRNTN_confs_item': {'RFX_SEM': 0.012495861124053738,
#   'RFX_WSSEM': 0.012132456735754561,
#   'RFX_pval': 0.40534849842988596,
#   'corr': 0.0030882762461709834,
#   'df': 17,
#   'stat': 0.23952695597013821},
#  'sentimentRNTN_rdm': {'RFX_SEM': 0.0087772889023239181,
#   'RFX_WSSEM': 0.0096782073485144893,
#   'RFX_pval': 0.17455097232136219,
#   'corr': 0.0041255917571707034,
#   'df': 17,
#   'stat': 0.93633264606508571},
#  'syntax_confs_item': {'RFX_SEM': 0.010915543308241927,
#   'RFX_WSSEM': 0.011064670459801484,
#   'RFX_pval': 0.22299084458849583,
#   'corr': 0.010852130325814538,
#   'df': 17,
#   'stat': 0.76213122354134877},
#  'syntax_rdm': {'RFX_SEM': 0.0078485717572015883,
#   'RFX_WSSEM': 0.0072817651704121522,
#   'RFX_pval': 0.27828970626059035,
#   'corr': 0.0070927318295739344,
#   'df': 17,
#   'stat': 0.58792980101761194},
#  'tfidf_confs_item': {'RFX_SEM': 0.011205952015071644,
#   'RFX_WSSEM': 0.0077342725189397492,
#   'RFX_pval': 0.0099045548449857197,
#   'corr': 0.029093567251461987,
#   'df': 17,
#   'stat': 2.3299440262549806},
#  'tfidf_rdm': {'RFX_SEM': 0.016918645506841828,
#   'RFX_WSSEM': 0.015074284440026019,
#   'RFX_pval': 0.013928549007653394,
#   'corr': 0.042673350041771085,
#   'df': 17,
#   'stat': 2.1992929593621779},
#  'valence_confs_item': {'RFX_SEM': 0.0096460438382419758,
#   'RFX_WSSEM': 0.0060390759737857036,
#   'RFX_pval': 0.035354660239343118,
#   'corr': 0.018897243107769423,
#   'df': 17,
#   'stat': 1.8073397586837701},
#  'valence_rdm': {'RFX_SEM': 0.01076524954527837,
#   'RFX_WSSEM': 0.0063502465868527421,
#   'RFX_pval': 0.12423277922793119,
#   'corr': 0.015406571985519349,
#   'df': 17,
#   'stat': 1.1540844242197568},
#  'valencearousal_confs_item': {'RFX_SEM': 0.0085680199657131671,
#   'RFX_WSSEM': 0.0048117987710732685,
#   'RFX_pval': 0.0069353404288854566,
#   'corr': 0.024379003063213587,
#   'df': 17,
#   'stat': 2.4605950931477834},
#  'valencearousal_rdm': {'RFX_SEM': 0.011180778642141046,
#   'RFX_WSSEM': 0.0061911437976940953,
#   'RFX_pval': 0.11552961497672648,
#   'corr': 0.017986633249791148,
#   'df': 17,
#   'stat': 1.197634779850691}}
