# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import sys
import matplotlib.pyplot as plt
sys.path.append('/mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/PyMVPA/') #for pymvpa
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
sys.path.insert(0,'/software/nipy-repo/nipy-suite/nibabel') #insert this so it gets used instead of nibabel in mypythonenv
sys.path.append('/software/python/anaconda/lib/python2.7/site-packages/') #for h5py
import numpy as np
import datetime
import pickle
import scipy
import h5py
import os
from mypymvpa.utilities.misc import makeIDs
import mypymvpa.utilities.misc as mum
import mypymvpa.utilities.visualization as viz
from mypymvpa.utilities.hardcodedexpparams import FGE_s,FGE_d,FGE_ds,FGE_rois
from mypymvpa.analysisobjs.mainobjs import Experiment
from mypymvpa.analysisobjs.dataset_funcs import preprocess, prepconfigV2
import pyanal.RSA_funcs as rsaf
from FGE_MISC.code.config import cfg,vizcfg
import FGE_MISC.code.vizfuncs as vizfuncs

# %%
#config details
# %autoreload
conditions=cfg.orderedemos
modelkeys=vizcfg.modelkeys

# %%
# define the experiment or load a saved exp
savesuffix='RSA'#"_matched_rois" #tag on the exp object
savetag='_RSA'#'_matched_rois' #tag on the individual subject savedir
rootdir='/mindhive/saxelab2/FGE/'
analdir=os.path.join(rootdir,'pymvparesults','Results_%s/' %(savesuffix))
roilist=FGE_rois['rois']
#roilist=['DMPFC_tomloc', 'MMPFC_tomloc']
datadir='/mindhive/saxelab/scripts/aesscripts/FGE_MISC/similarityspaces'
rdmfile=os.path.join(datadir,'comparisonRDMs.pkl')

# %%
#define our model RDMs
# %autoreload
with open(rdmfile, 'r') as inputfile:
    modelRDMs = pickle.load(inputfile)

# %%
# %autoreload
roi_summaries={}
for roi in roilist:
    filename='%sResultsSummary_%s.pkl' %(analdir, roi)
    rs=mum.loadpickledobject(filename)
    roi_summaries[roi]=rs
    rs.summarize_grn2models(models2show=vizcfg.modelkeys, modelcolors=vizcfg.modelcolors, ylim=[-.1,.4])
    rs.summarize_grn2modelsRFX(models2show=vizcfg.modelkeys,modelcolors=vizcfg.modelcolors,ylim=[-.05,.20],errorbars='ws', noiseceiling=rs.noiseceiling)#'ws'
    rs.summarize_grnmodelcomparisonsRFX(models2show=vizcfg.modelkeys, showstats=['37dim_rdm'])
# Out:
# 37dim_rdm: corr(SEM)=0.26(0.08), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.15(0.07), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.18(0.07), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.14(0.07), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.18(0.06), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.09(0.07), p(permutation test)=0.020
# sentimentRNTN_rdm: corr(SEM)=0.04(0.07), p(permutation test)=0.170
# intensity_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.010
# arousal_rdm_VS_37dim_rdm: M1=0.05, M2=0.07, z(21)=0.80, p=0.426.
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.07, z(21)=1.96, p=0.050. ***
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.08, p=0.002. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.04, M2=0.07, z(21)=3.65, p=0.000. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.01, M2=0.07, z(21)=3.17, p=0.002. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.07, z(21)=2.39, p=0.017. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.07, M2=0.05, z(21)=3.17, p=0.002. ***
# 37dim_rdm: corr(SEM)=0.24(0.08), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.010
# valencearousal_rdm: corr(SEM)=0.15(0.08), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.10(0.07), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.20(0.07), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.13(0.06), p(permutation test)=0.020
# sentimentRNTN_rdm: corr(SEM)=-0.01(0.06), p(permutation test)=0.370
# intensity_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.000
# arousal_rdm_VS_37dim_rdm: M1=0.06, M2=0.06, z(21)=0.18, p=0.858.
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(21)=2.22, p=0.026. ***
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=3.39, p=0.001. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=2.94, p=0.003. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=-0.00, M2=0.06, z(21)=3.10, p=0.002. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(21)=1.83, p=0.067.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(21)=2.91, p=0.004. ***
# 37dim_rdm: corr(SEM)=0.22(0.07), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.11(0.06), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.15(0.07), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.17(0.05), p(permutation test)=0.000
# sentimentBoW_rdm: corr(SEM)=0.04(0.06), p(permutation test)=0.300
# sentimentRNTN_rdm: corr(SEM)=0.04(0.08), p(permutation test)=0.150
# intensity_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.000
# arousal_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=0.85, p=0.394.
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=1.58, p=0.114.
# valence_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(20)=2.52, p=0.012. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(20)=3.11, p=0.002. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(20)=2.49, p=0.013. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.01, M2=0.06, z(20)=2.94, p=0.003. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(20)=1.93, p=0.054.
# 37dim_rdm: corr(SEM)=0.16(0.05), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.09(0.04), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.09(0.04), p(permutation test)=0.020
# valence_rdm: corr(SEM)=0.06(0.04), p(permutation test)=0.040
# arousal_rdm: corr(SEM)=0.12(0.05), p(permutation test)=0.010
# sentimentBoW_rdm: corr(SEM)=0.14(0.05), p(permutation test)=0.010
# sentimentRNTN_rdm: corr(SEM)=0.02(0.04), p(permutation test)=0.320
# intensity_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.050
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.04, z(21)=1.28, p=0.200.
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.04, z(21)=2.35, p=0.019. ***
# valence_rdm_VS_37dim_rdm: M1=0.02, M2=0.04, z(21)=2.81, p=0.005. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.03, M2=0.04, z(21)=2.42, p=0.016. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=0.00, M2=0.04, z(21)=2.55, p=0.011. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.04, M2=0.04, z(21)=0.54, p=0.592.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.04, M2=0.02, z(21)=2.39, p=0.017. ***
# 37dim_rdm: corr(SEM)=0.29(0.06), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.20(0.06), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.20(0.07), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.19(0.06), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.010
# sentimentBoW_rdm: corr(SEM)=0.12(0.06), p(permutation test)=0.000
# sentimentRNTN_rdm: corr(SEM)=-0.04(0.06), p(permutation test)=0.140
# intensity_rdm: corr(SEM)=0.07(0.04), p(permutation test)=0.030
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.08, z(19)=2.99, p=0.003. ***
# intensity_rdm_VS_37dim_rdm: M1=0.02, M2=0.08, z(19)=3.17, p=0.002. ***
# valence_rdm_VS_37dim_rdm: M1=0.06, M2=0.08, z(19)=2.91, p=0.004. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.06, M2=0.08, z(19)=2.84, p=0.005. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=-0.02, M2=0.08, z(19)=3.43, p=0.001. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.03, M2=0.08, z(19)=2.46, p=0.014. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.08, M2=0.06, z(19)=3.06, p=0.002. ***
# 37dim_rdm: corr(SEM)=0.21(0.05), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.12(0.05), p(permutation test)=0.000
# valencearousal_rdm: corr(SEM)=0.14(0.06), p(permutation test)=0.000
# valence_rdm: corr(SEM)=0.12(0.05), p(permutation test)=0.000
# arousal_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.010
# sentimentBoW_rdm: corr(SEM)=0.10(0.04), p(permutation test)=0.010
# sentimentRNTN_rdm: corr(SEM)=-0.00(0.05), p(permutation test)=0.500
# intensity_rdm: corr(SEM)=0.10(0.05), p(permutation test)=0.000
# arousal_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=1.87, p=0.062.
# intensity_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=1.98, p=0.048. ***
# valence_rdm_VS_37dim_rdm: M1=0.03, M2=0.06, z(19)=2.61, p=0.009. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.04, M2=0.06, z(19)=2.02, p=0.044. ***
# sentimentRNTN_rdm_VS_37dim_rdm: M1=-0.00, M2=0.06, z(19)=2.46, p=0.014. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.06, z(19)=1.98, p=0.048. ***
# 37dim_rdm_VS_valencearousal_rdm: M1=0.06, M2=0.04, z(19)=2.76, p=0.006. ***
# 37dim_rdm: corr(SEM)=0.11(0.04), p(permutation test)=0.000
# basicemo_rdm: corr(SEM)=0.05(0.04), p(permutation test)=0.030
# valencearousal_rdm: corr(SEM)=0.05(0.04), p(permutation test)=0.090
# valence_rdm: corr(SEM)=0.05(0.04), p(permutation test)=0.130
# arousal_rdm: corr(SEM)=0.08(0.05), p(permutation test)=0.020
# sentimentBoW_rdm: corr(SEM)=0.10(0.06), p(permutation test)=0.050
# sentimentRNTN_rdm: corr(SEM)=-0.05(0.04), p(permutation test)=0.150
# intensity_rdm: corr(SEM)=0.05(0.04), p(permutation test)=0.040
# arousal_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=1.02, p=0.306.
# intensity_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=1.50, p=0.133.
# valence_rdm_VS_37dim_rdm: M1=0.01, M2=0.03, z(17)=2.29, p=0.022. ***
# basicemo_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=1.85, p=0.064.
# sentimentRNTN_rdm_VS_37dim_rdm: M1=-0.01, M2=0.03, z(17)=2.20, p=0.028. ***
# sentimentBoW_rdm_VS_37dim_rdm: M1=0.02, M2=0.03, z(17)=0.02, p=0.983.
# 37dim_rdm_VS_valencearousal_rdm: M1=0.03, M2=0.02, z(17)=2.50, p=0.012. ***

# %%
# %autoreload
#timecourse analysis
tcobjs=mum.loadpickledobject(os.path.join(analdir, 'timecourse', 'tcobjs.pkl'))
vizfuncs.plottcresults(tcobjs, roilist)
